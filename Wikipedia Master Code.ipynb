# %% [markdown]
# # Master code for the Wikipedia data

# %% [markdown]
# ### Mariana, Chichi, Nate, and Taylor

# %%
# Import statements
import requests as rq
from bs4 import BeautifulSoup
import pandas as pd
from collections import defaultdict
import numpy as np
from datetime import datetime as dt

# %% [markdown]
# ## Part 1: Getting data about every episode from seasons 9-18

# %% [markdown]
# #### Defining global variables

# %%
# Defining some primary variables

# Seasons we are interested in
seasons = list(range(9, 19))

# URL to Wikipedia page of the seasons and episodes
seasons_url = 'https://en.wikipedia.org/wiki/List_of_The_Bachelorette_(American_TV_series)_episodes'

# Base URL for Wikipedia pages of every season – to be formatted later
url_base = "https://en.wikipedia.org/wiki/The_Bachelorette_(American_season_%i)"

# %% [markdown]
# #### Getting every table from the Wikipedia page with information about every season

# %%
# Getting all the tables from the wikipedia page
page = rq.get(seasons_url)

# accessing page contents
soup = BeautifulSoup(page.content)

# parsing the contents as html
soup = BeautifulSoup(page.text, 'html.parser')

# finding all the wikitables
tables =soup.find_all('table', {'class':"wikitable"})

# Saving all the tables as dataframes to a list
all_tables = []
for table in tables:
    # reading the request as an html document
    df = pd.read_html(str(table))
    
    # saving it as a dataframe
    df = pd.DataFrame(df[0])
    
    # appending said dataframe to the list
    all_tables.append(df)

# %% [markdown]
# #### Formatting the tables as needed

# %%
# Formatting the tables as we need them to be:

# removing a double-layer column labels
all_tables[0].columns = [col[1] for col in all_tables[0].columns]

# setting the indices of the dataframe to the season number
all_tables[0].index = all_tables[0]["Season.1"]

# Dropping redundant columns caused by two-layer column labels
all_tables[0].drop(columns=["Season", "Season.1", "Episodes.1"],inplace=True)

# removing weird last table
all_tables.pop(-1)


# checking we are right
all_tables[18]
# Out:
#     No.overall  No. inseason                      Title  \
# 0          193             1  "Week 1: Season Premiere"
# 1          194             2                   "Week 2"
# 2          195             3                   "Week 3"
# 3          196             4                   "Week 4"
# 4          197             5                   "Week 5"
# 5          198             6                   "Week 6"
# 6          199             7   "Week 7: Hometown Dates"
# 7          200             8         "The Men Tell All"
# 8          201             9   "Week 8: Fantasy Suites"
# 9          202            10           "Week 9: Finale"
# 10         203            11     "After the Final Rose"
#
#    Original air date [156]  Prod.code [156] U.S. viewers(millions)  \
# 0         October 19, 2021           1801.0              3.00[157]
# 1         October 26, 2021           1802.0              2.87[158]
# 2         November 2, 2021           1803.0              2.74[159]
# 3         November 9, 2021           1804.0              2.60[160]
# 4        November 16, 2021           1805.0              2.98[161]
# 5        November 23, 2021           1806.0              2.71[162]
# 6        November 30, 2021           1807.0              3.07[163]
# 7         December 6, 2021              NaN                    TBD
# 8        December 14, 2021           1808.0                    TBD
# 9        December 21, 2021           1809.0                    TBD
# 10       December 21, 2021              NaN                    TBD
#
#    Rating(18–49)
# 0     0.8/4[157]
# 1     0.7/3[158]
# 2     0.7/3[159]
# 3     0.6/4[160]
# 4       0.7[161]
# 5     0.6/3[162]
# 6     0.6/7[163]
# 7            TBA
# 8            TBA
# 9            TBA
# 10           TBA

# %% [markdown]
# #### Saving the tables in a dictionary keyed by season number

# %%
# now we want to have the tables saved in a dictionary with the key being the season number
seasons_table = defaultdict()

for i in range(9, 19):
    seasons_table[str(i)] = all_tables[i]


# Dictionary keyed by the season number with all episodes as dataframes
# Only includes seasons 9-18

# normalizing the column names for easier cleaning
for table in seasons_table.keys():
    seasons_table[table].columns = ["Episode Number", "In-Season Episode", "Title", "Original Air Date", "Prod Code", "Viewers", "Rating"]

# %% [markdown]
# #### Only extracing the relevant data (i..e Season episode number, title, air date)

# %%
# Now we want to extract only the data we want
season_episodes_dates = []

# Going through each table which referrs to each season
for season in seasons_table.keys():
    
    # and then for each episode in the season
    for episode in range(len(seasons_table[season])):
        
        # save the airing date as a variable to be used to make it a datetime object
        date = seasons_table[season]["Original Air Date"].iloc[episode]
        
        # removing weird nuances in the wikipedia page (from citations)
        if date[-1] == "]":
            date = date[0:-3]
        
        # saving that date (encoded as unicode) as an ascii encoded datetime object
        date_time = dt.strptime(date.replace("\xa0", " "), "%B %d, %Y")
        
        # saving the data to a list in the format of:
        # [Season number, episode number, and unified datetime]
        season_episodes_dates.append([season, seasons_table[season]["In-Season Episode"].iloc[episode], seasons_table[season]["Title"].iloc[episode], str(date_time)[:10]])

# %% [markdown]
# ### Now we have the data formatted as
#     [Season #, Episode Number, Title of Episode, Date of Airing]

# %% [markdown]
# #### Now we want to save this data as a DataFrame for easier manipulation in Part 2

# %%
# Creating a dataframe with the data and normalizing the columns
s_e_d = pd.DataFrame(season_episodes_dates)
s_e_d.columns = ["Season", "Episode", "Title", "Date Aired"]

# Making the episode titles normalized
for i in range(len(s_e_d)):
    s_e_d["Title"].iloc[i] = s_e_d["Title"].iloc[i].split(":")[0].replace("\"", "")
    
s_e_d.head(20)
# Out:
# /Users/taylor/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#    Season  Episode                 Title  Date Aired
# 0       9        1                Week 1  2013-05-27
# 1       9        2                Week 2  2013-06-03
# 2       9        3                Week 3  2013-06-10
# 3       9        4                Week 4  2013-06-17
# 4       9        5                Week 5  2013-06-24
# 5       9        6                Week 6  2013-07-01
# 6       9        7                Week 7  2013-07-08
# 7       9        8                Week 8  2013-07-15
# 8       9        9      The Men Tell All  2013-07-22
# 9       9       10                Week 9  2013-07-29
# 10      9       11               Week 10  2013-08-05
# 11      9       12  After the Final Rose  2013-08-05
# 12     10        1                Week 1  2014-05-19
# 13     10        2                Week 2  2014-05-26
# 14     10        3                Week 3  2014-06-01
# 15     10        4                Week 4  2014-06-02
# 16     10        5    The Journey So Far  2014-06-09
# 17     10        6                Week 5  2014-06-16
# 18     10        7                Week 6  2014-06-23
# 19     10        8                Week 7  2014-06-30

# %% [markdown]
# #### Saving this dataframe as a csv to do some manual cleanup of two-part episodes and finnicky edge cases

# %%
s_e_d.to_csv("./season_data.csv")

# %% [markdown]
# ## Part 2: Contestant Data

# %% [markdown]
# #### Defining a function to derive the useful information from each season's wikipedia page in the form of
#     [Name, Episode Voted Off]

# %%
def get_names_outcomes(season):
    url = url_base % season
    
    # Getting all the tables from the wikipedia page
    page = rq.get(url)

    # accessing page contents
    soup = BeautifulSoup(page.content)

    # parsing the contents as html
    soup = BeautifulSoup(page.text, 'html.parser')

    # finding all the wikitables
    tables =soup.find_all('table', {'class':"wikitable"})

    # get the first table on the page
    contestants = tables[0]

    # reading the request as an html document
    df = pd.read_html(str(contestants))

    # saving it as a dataframe
    df = pd.DataFrame(df[0])

    # isolating the columns we want
    names = df["Name"]
    outcome = df["Outcome"].values
    names_clean = []

    # stupid cleaning of the names because BS doesnt take out references!
    for name in names:
        names_clean.append(name.split("[")[0])

    # getting the data ready for the dataframe
    data = {"Name": names_clean,
            "Voted Off": outcome}

    # creating and returing the dataframe
    to_return = pd.DataFrame(data=data, columns=["Name", "Voted Off"])

    return to_return

# %%
tables_of_seasons = defaultdict()

# Getting contestants for all seasons
for season in seasons:
    tables_of_seasons[season] = get_names_outcomes(season)

# %% [markdown]
# ## Part 3: Combining the DataFrames

# %% [markdown]
# #### Defining global variables and renaming dataframes

# %%
# Global list of season numbers
seasons = list(range(9, 19))

# renaming s_e_d
# Type: DataFrame
season_data = pd.read_csv("./season_data.csv")

# renaming the tables_of_seasons
# Type: Dictionary of dataframes, keyed by season number
contestant_data = tables_of_seasons

# %% [markdown]
# #### Iterate through the seasons and extract contestant information n times, where n is the number of episodes in that season

# %% [markdown]
# #### We want our initial table to look like this for now
#
# |Season|Episode|Title|Date Aired|Contestants|Voted Off|
# |--|--|--|--|--|--|
# |Type: int|Type: int|Type: str|Type: datetime|Type: list|Type: NA|

# %% [markdown]
# #### Fixing the weird indexing column in the imported dataframe

# %%
season_data.drop(columns=["Unnamed: 0"], inplace=True)
season_data
# Out:
#      Season  Episode                 Title  Date Aired
# 0         9        1                Week 1  2013-05-27
# 1         9        2                Week 2  2013-06-03
# 2         9        3                Week 3  2013-06-10
# 3         9        4                Week 4  2013-06-17
# 4         9        5                Week 5  2013-06-24
# ..      ...      ...                   ...         ...
# 114      18        7                Week 7  2021-11-30
# 115      18        8      The Men Tell All  2021-12-06
# 116      18        9                Week 8  2021-12-14
# 117      18       10                Week 9  2021-12-21
# 118      18       11  After the Final Rose  2021-12-21
#
# [119 rows x 4 columns]

# %% [markdown]
# #### Creating a list of lists with the same dimensions of the `season_data` variable. Each list will contain all the contestants from that season.

# %%
df_of_lists = []

for season in seasons:
    contestants = contestant_data[season]["Name"].values
    for i in range(len(season_data[season_data["Season"] == season])):
        df_of_lists.append(contestants)
        
df_of_lists
# Out:
# [array(['Chris Siegfried', 'Drew Kenney', 'Brooks Forester', 'Zak Waddell',
#         'Michael Garofola', 'James Case', 'Juan Pablo Galavis',
#         'Kasey Stewart', 'Mikey Tenerelli', 'Ben Scott', 'Bryden Vukasin',
#         'Zack Kalter', 'Brad McKinzie', 'Brandon Andreen', 'Dan Cox',
#         'Brian Jarosinski', 'Nick Mucci', 'Robert Graham', 'Will Reese',
#         'Diogo Custodio', 'Larry Burchett', 'Micah Heisler', 'Mike R.',
#         'Nick Roy', 'Jonathan Vollinger'], dtype=object),
#  array(['Chris Siegfried', 'Drew Kenney', 'Brooks Forester', 'Zak Waddell',
#         'Michael Garofola', 'James Case', 'Juan Pablo Galavis',
#         'Kasey Stewart', 'Mikey Tenerelli', 'Ben Scott', 'Bryden Vukasin',
#         'Zack Kalter', 'Brad McKinzie', 'Brandon Andreen', 'Dan Cox',
#         'Brian Jarosinski', 'Nick Mucci', 'Robert Graham', 'Will Reese',
#         'Diogo Custodio', 'Larry Burchett', 'Micah Heisler', 'Mike R.',
#         'Nick Roy', 'Jonathan Vollinger'], dtype=object),
#  array(['Chris Siegfried', 'Drew Kenney', 'Brooks Forester', 'Zak Waddell',
#         'Michael Garofola', 'James Case', 'Juan Pablo Galavis',
#         'Kasey Stewart', 'Mikey Tenerelli', 'Ben Scott', 'Bryden Vukasin',
#         'Zack Kalter', 'Brad McKinzie', 'Brandon Andreen', 'Dan Cox',
#         'Brian Jarosinski', 'Nick Mucci', 'Robert Graham', 'Will Reese',
#         'Diogo Custodio', 'Larry Burchett', 'Micah Heisler', 'Mike R.',
#         'Nick Roy', 'Jonathan Vollinger'], dtype=object),
#  array(['Chris Siegfried', 'Drew Kenney', 'Brooks Forester', 'Zak Waddell',
#         'Michael Garofola', 'James Case', 'Juan Pablo Galavis',
#         'Kasey Stewart', 'Mikey Tenerelli', 'Ben Scott', 'Bryden Vukasin',
#         'Zack Kalter', 'Brad McKinzie', 'Brandon Andreen', 'Dan Cox',
#         'Brian Jarosinski', 'Nick Mucci', 'Robert Graham', 'Will Reese',
#         'Diogo Custodio', 'Larry Burchett', 'Micah Heisler', 'Mike R.',
#         'Nick Roy', 'Jonathan Vollinger'], dtype=object),
#  array(['Chris Siegfried', 'Drew Kenney', 'Brooks Forester', 'Zak Waddell',
#         'Michael Garofola', 'James Case', 'Juan Pablo Galavis',
#         'Kasey Stewart', 'Mikey Tenerelli', 'Ben Scott', 'Bryden Vukasin',
#         'Zack Kalter', 'Brad McKinzie', 'Brandon Andreen', 'Dan Cox',
#         'Brian Jarosinski', 'Nick Mucci', 'Robert Graham', 'Will Reese',
#         'Diogo Custodio', 'Larry Burchett', 'Micah Heisler', 'Mike R.',
#         'Nick Roy', 'Jonathan Vollinger'], dtype=object),
#  array(['Chris Siegfried', 'Drew Kenney', 'Brooks Forester', 'Zak Waddell',
#         'Michael Garofola', 'James Case', 'Juan Pablo Galavis',
#         'Kasey Stewart', 'Mikey Tenerelli', 'Ben Scott', 'Bryden Vukasin',
#         'Zack Kalter', 'Brad McKinzie', 'Brandon Andreen', 'Dan Cox',
#         'Brian Jarosinski', 'Nick Mucci', 'Robert Graham', 'Will Reese',
#         'Diogo Custodio', 'Larry Burchett', 'Micah Heisler', 'Mike R.',
#         'Nick Roy', 'Jonathan Vollinger'], dtype=object),
#  array(['Chris Siegfried', 'Drew Kenney', 'Brooks Forester', 'Zak Waddell',
#         'Michael Garofola', 'James Case', 'Juan Pablo Galavis',
#         'Kasey Stewart', 'Mikey Tenerelli', 'Ben Scott', 'Bryden Vukasin',
#         'Zack Kalter', 'Brad McKinzie', 'Brandon Andreen', 'Dan Cox',
#         'Brian Jarosinski', 'Nick Mucci', 'Robert Graham', 'Will Reese',
#         'Diogo Custodio', 'Larry Burchett', 'Micah Heisler', 'Mike R.',
#         'Nick Roy', 'Jonathan Vollinger'], dtype=object),
#  array(['Chris Siegfried', 'Drew Kenney', 'Brooks Forester', 'Zak Waddell',
#         'Michael Garofola', 'James Case', 'Juan Pablo Galavis',
#         'Kasey Stewart', 'Mikey Tenerelli', 'Ben Scott', 'Bryden Vukasin',
#         'Zack Kalter', 'Brad McKinzie', 'Brandon Andreen', 'Dan Cox',
#         'Brian Jarosinski', 'Nick Mucci', 'Robert Graham', 'Will Reese',
#         'Diogo Custodio', 'Larry Burchett', 'Micah Heisler', 'Mike R.',
#         'Nick Roy', 'Jonathan Vollinger'], dtype=object),
#  array(['Chris Siegfried', 'Drew Kenney', 'Brooks Forester', 'Zak Waddell',
#         'Michael Garofola', 'James Case', 'Juan Pablo Galavis',
#         'Kasey Stewart', 'Mikey Tenerelli', 'Ben Scott', 'Bryden Vukasin',
#         'Zack Kalter', 'Brad McKinzie', 'Brandon Andreen', 'Dan Cox',
#         'Brian Jarosinski', 'Nick Mucci', 'Robert Graham', 'Will Reese',
#         'Diogo Custodio', 'Larry Burchett', 'Micah Heisler', 'Mike R.',
#         'Nick Roy', 'Jonathan Vollinger'], dtype=object),
#  array(['Chris Siegfried', 'Drew Kenney', 'Brooks Forester', 'Zak Waddell',
#         'Michael Garofola', 'James Case', 'Juan Pablo Galavis',
#         'Kasey Stewart', 'Mikey Tenerelli', 'Ben Scott', 'Bryden Vukasin',
#         'Zack Kalter', 'Brad McKinzie', 'Brandon Andreen', 'Dan Cox',
#         'Brian Jarosinski', 'Nick Mucci', 'Robert Graham', 'Will Reese',
#         'Diogo Custodio', 'Larry Burchett', 'Micah Heisler', 'Mike R.',
#         'Nick Roy', 'Jonathan Vollinger'], dtype=object),
#  array(['Chris Siegfried', 'Drew Kenney', 'Brooks Forester', 'Zak Waddell',
#         'Michael Garofola', 'James Case', 'Juan Pablo Galavis',
#         'Kasey Stewart', 'Mikey Tenerelli', 'Ben Scott', 'Bryden Vukasin',
#         'Zack Kalter', 'Brad McKinzie', 'Brandon Andreen', 'Dan Cox',
#         'Brian Jarosinski', 'Nick Mucci', 'Robert Graham', 'Will Reese',
#         'Diogo Custodio', 'Larry Burchett', 'Micah Heisler', 'Mike R.',
#         'Nick Roy', 'Jonathan Vollinger'], dtype=object),
#  array(['Chris Siegfried', 'Drew Kenney', 'Brooks Forester', 'Zak Waddell',
#         'Michael Garofola', 'James Case', 'Juan Pablo Galavis',
#         'Kasey Stewart', 'Mikey Tenerelli', 'Ben Scott', 'Bryden Vukasin',
#         'Zack Kalter', 'Brad McKinzie', 'Brandon Andreen', 'Dan Cox',
#         'Brian Jarosinski', 'Nick Mucci', 'Robert Graham', 'Will Reese',
#         'Diogo Custodio', 'Larry Burchett', 'Micah Heisler', 'Mike R.',
#         'Nick Roy', 'Jonathan Vollinger'], dtype=object),
#  array(['Josh Murray', 'Nick Viall', 'Chris Soules', 'Marcus Grodd',
#         'Brian Osborne', 'Dylan Petitt', 'Joseph John "J.J." O\'Brien',
#         'Cody Sattler', 'Andrew Poole', 'Marquel Martin',
#         'Patrick Jagodzinski', 'Tasos Hernandez', 'Eric Hill',
#         'Bradley Wisk', 'Brett Melnick', 'Ron Worrell', 'Carl King',
#         'Craig Muhlbauer', 'Nick Sutter', 'Emil Schaffroth', 'Jason Leep',
#         'Josh Bauer', 'Mike Campanelli', 'Rudie Dane', 'Steven Woolworth'],
#        dtype=object),
#  array(['Josh Murray', 'Nick Viall', 'Chris Soules', 'Marcus Grodd',
#         'Brian Osborne', 'Dylan Petitt', 'Joseph John "J.J." O\'Brien',
#         'Cody Sattler', 'Andrew Poole', 'Marquel Martin',
#         'Patrick Jagodzinski', 'Tasos Hernandez', 'Eric Hill',
#         'Bradley Wisk', 'Brett Melnick', 'Ron Worrell', 'Carl King',
#         'Craig Muhlbauer', 'Nick Sutter', 'Emil Schaffroth', 'Jason Leep',
#         'Josh Bauer', 'Mike Campanelli', 'Rudie Dane', 'Steven Woolworth'],
#        dtype=object),
#  array(['Josh Murray', 'Nick Viall', 'Chris Soules', 'Marcus Grodd',
#         'Brian Osborne', 'Dylan Petitt', 'Joseph John "J.J." O\'Brien',
#         'Cody Sattler', 'Andrew Poole', 'Marquel Martin',
#         'Patrick Jagodzinski', 'Tasos Hernandez', 'Eric Hill',
#         'Bradley Wisk', 'Brett Melnick', 'Ron Worrell', 'Carl King',
#         'Craig Muhlbauer', 'Nick Sutter', 'Emil Schaffroth', 'Jason Leep',
#         'Josh Bauer', 'Mike Campanelli', 'Rudie Dane', 'Steven Woolworth'],
#        dtype=object),
#  array(['Josh Murray', 'Nick Viall', 'Chris Soules', 'Marcus Grodd',
#         'Brian Osborne', 'Dylan Petitt', 'Joseph John "J.J." O\'Brien',
#         'Cody Sattler', 'Andrew Poole', 'Marquel Martin',
#         'Patrick Jagodzinski', 'Tasos Hernandez', 'Eric Hill',
#         'Bradley Wisk', 'Brett Melnick', 'Ron Worrell', 'Carl King',
#         'Craig Muhlbauer', 'Nick Sutter', 'Emil Schaffroth', 'Jason Leep',
#         'Josh Bauer', 'Mike Campanelli', 'Rudie Dane', 'Steven Woolworth'],
#        dtype=object),
#  array(['Josh Murray', 'Nick Viall', 'Chris Soules', 'Marcus Grodd',
#         'Brian Osborne', 'Dylan Petitt', 'Joseph John "J.J." O\'Brien',
#         'Cody Sattler', 'Andrew Poole', 'Marquel Martin',
#         'Patrick Jagodzinski', 'Tasos Hernandez', 'Eric Hill',
#         'Bradley Wisk', 'Brett Melnick', 'Ron Worrell', 'Carl King',
#         'Craig Muhlbauer', 'Nick Sutter', 'Emil Schaffroth', 'Jason Leep',
#         'Josh Bauer', 'Mike Campanelli', 'Rudie Dane', 'Steven Woolworth'],
#        dtype=object),
#  array(['Josh Murray', 'Nick Viall', 'Chris Soules', 'Marcus Grodd',
#         'Brian Osborne', 'Dylan Petitt', 'Joseph John "J.J." O\'Brien',
#         'Cody Sattler', 'Andrew Poole', 'Marquel Martin',
#         'Patrick Jagodzinski', 'Tasos Hernandez', 'Eric Hill',
#         'Bradley Wisk', 'Brett Melnick', 'Ron Worrell', 'Carl King',
#         'Craig Muhlbauer', 'Nick Sutter', 'Emil Schaffroth', 'Jason Leep',
#         'Josh Bauer', 'Mike Campanelli', 'Rudie Dane', 'Steven Woolworth'],
#        dtype=object),
#  array(['Josh Murray', 'Nick Viall', 'Chris Soules', 'Marcus Grodd',
#         'Brian Osborne', 'Dylan Petitt', 'Joseph John "J.J." O\'Brien',
#         'Cody Sattler', 'Andrew Poole', 'Marquel Martin',
#         'Patrick Jagodzinski', 'Tasos Hernandez', 'Eric Hill',
#         'Bradley Wisk', 'Brett Melnick', 'Ron Worrell', 'Carl King',
#         'Craig Muhlbauer', 'Nick Sutter', 'Emil Schaffroth', 'Jason Leep',
#         'Josh Bauer', 'Mike Campanelli', 'Rudie Dane', 'Steven Woolworth'],
#        dtype=object),
#  array(['Josh Murray', 'Nick Viall', 'Chris Soules', 'Marcus Grodd',
#         'Brian Osborne', 'Dylan Petitt', 'Joseph John "J.J." O\'Brien',
#         'Cody Sattler', 'Andrew Poole', 'Marquel Martin',
#         'Patrick Jagodzinski', 'Tasos Hernandez', 'Eric Hill',
#         'Bradley Wisk', 'Brett Melnick', 'Ron Worrell', 'Carl King',
#         'Craig Muhlbauer', 'Nick Sutter', 'Emil Schaffroth', 'Jason Leep',
#         'Josh Bauer', 'Mike Campanelli', 'Rudie Dane', 'Steven Woolworth'],
#        dtype=object),
#  array(['Josh Murray', 'Nick Viall', 'Chris Soules', 'Marcus Grodd',
#         'Brian Osborne', 'Dylan Petitt', 'Joseph John "J.J." O\'Brien',
#         'Cody Sattler', 'Andrew Poole', 'Marquel Martin',
#         'Patrick Jagodzinski', 'Tasos Hernandez', 'Eric Hill',
#         'Bradley Wisk', 'Brett Melnick', 'Ron Worrell', 'Carl King',
#         'Craig Muhlbauer', 'Nick Sutter', 'Emil Schaffroth', 'Jason Leep',
#         'Josh Bauer', 'Mike Campanelli', 'Rudie Dane', 'Steven Woolworth'],
#        dtype=object),
#  array(['Josh Murray', 'Nick Viall', 'Chris Soules', 'Marcus Grodd',
#         'Brian Osborne', 'Dylan Petitt', 'Joseph John "J.J." O\'Brien',
#         'Cody Sattler', 'Andrew Poole', 'Marquel Martin',
#         'Patrick Jagodzinski', 'Tasos Hernandez', 'Eric Hill',
#         'Bradley Wisk', 'Brett Melnick', 'Ron Worrell', 'Carl King',
#         'Craig Muhlbauer', 'Nick Sutter', 'Emil Schaffroth', 'Jason Leep',
#         'Josh Bauer', 'Mike Campanelli', 'Rudie Dane', 'Steven Woolworth'],
#        dtype=object),
#  array(['Josh Murray', 'Nick Viall', 'Chris Soules', 'Marcus Grodd',
#         'Brian Osborne', 'Dylan Petitt', 'Joseph John "J.J." O\'Brien',
#         'Cody Sattler', 'Andrew Poole', 'Marquel Martin',
#         'Patrick Jagodzinski', 'Tasos Hernandez', 'Eric Hill',
#         'Bradley Wisk', 'Brett Melnick', 'Ron Worrell', 'Carl King',
#         'Craig Muhlbauer', 'Nick Sutter', 'Emil Schaffroth', 'Jason Leep',
#         'Josh Bauer', 'Mike Campanelli', 'Rudie Dane', 'Steven Woolworth'],
#        dtype=object),
#  array(['Josh Murray', 'Nick Viall', 'Chris Soules', 'Marcus Grodd',
#         'Brian Osborne', 'Dylan Petitt', 'Joseph John "J.J." O\'Brien',
#         'Cody Sattler', 'Andrew Poole', 'Marquel Martin',
#         'Patrick Jagodzinski', 'Tasos Hernandez', 'Eric Hill',
#         'Bradley Wisk', 'Brett Melnick', 'Ron Worrell', 'Carl King',
#         'Craig Muhlbauer', 'Nick Sutter', 'Emil Schaffroth', 'Jason Leep',
#         'Josh Bauer', 'Mike Campanelli', 'Rudie Dane', 'Steven Woolworth'],
#        dtype=object),
#  array(['Josh Murray', 'Nick Viall', 'Chris Soules', 'Marcus Grodd',
#         'Brian Osborne', 'Dylan Petitt', 'Joseph John "J.J." O\'Brien',
#         'Cody Sattler', 'Andrew Poole', 'Marquel Martin',
#         'Patrick Jagodzinski', 'Tasos Hernandez', 'Eric Hill',
#         'Bradley Wisk', 'Brett Melnick', 'Ron Worrell', 'Carl King',
#         'Craig Muhlbauer', 'Nick Sutter', 'Emil Schaffroth', 'Jason Leep',
#         'Josh Bauer', 'Mike Campanelli', 'Rudie Dane', 'Steven Woolworth'],
#        dtype=object),
#  array(['Shawn Booth', 'Nick Viall', 'Ben Higgins', 'Jared Haibon',
#         'Joe Bailey', 'Chris Strandburg', 'Ben Zorn', 'Tanner Tolbert',
#         'John "J.J." Lane III', 'Joshua Albers', 'Justin Reich',
#         'Ian Thomson', 'Corey Stansell', 'Jonathan Holloway',
#         'Ryan Beckett', 'Clint Arlis', 'Tony Harris', 'Cory Shivar',
#         'Daniel Finney', 'Kupah James', 'Bradley Cox', 'David',
#         'Josh Seiter', 'Shawn Evans', 'Brady Toops', 'Ryan McDill'],
#        dtype=object),
#  array(['Shawn Booth', 'Nick Viall', 'Ben Higgins', 'Jared Haibon',
#         'Joe Bailey', 'Chris Strandburg', 'Ben Zorn', 'Tanner Tolbert',
#         'John "J.J." Lane III', 'Joshua Albers', 'Justin Reich',
#         'Ian Thomson', 'Corey Stansell', 'Jonathan Holloway',
#         'Ryan Beckett', 'Clint Arlis', 'Tony Harris', 'Cory Shivar',
#         'Daniel Finney', 'Kupah James', 'Bradley Cox', 'David',
#         'Josh Seiter', 'Shawn Evans', 'Brady Toops', 'Ryan McDill'],
#        dtype=object),
#  array(['Shawn Booth', 'Nick Viall', 'Ben Higgins', 'Jared Haibon',
#         'Joe Bailey', 'Chris Strandburg', 'Ben Zorn', 'Tanner Tolbert',
#         'John "J.J." Lane III', 'Joshua Albers', 'Justin Reich',
#         'Ian Thomson', 'Corey Stansell', 'Jonathan Holloway',
#         'Ryan Beckett', 'Clint Arlis', 'Tony Harris', 'Cory Shivar',
#         'Daniel Finney', 'Kupah James', 'Bradley Cox', 'David',
#         'Josh Seiter', 'Shawn Evans', 'Brady Toops', 'Ryan McDill'],
#        dtype=object),
#  array(['Shawn Booth', 'Nick Viall', 'Ben Higgins', 'Jared Haibon',
#         'Joe Bailey', 'Chris Strandburg', 'Ben Zorn', 'Tanner Tolbert',
#         'John "J.J." Lane III', 'Joshua Albers', 'Justin Reich',
#         'Ian Thomson', 'Corey Stansell', 'Jonathan Holloway',
#         'Ryan Beckett', 'Clint Arlis', 'Tony Harris', 'Cory Shivar',
#         'Daniel Finney', 'Kupah James', 'Bradley Cox', 'David',
#         'Josh Seiter', 'Shawn Evans', 'Brady Toops', 'Ryan McDill'],
#        dtype=object),
#  array(['Shawn Booth', 'Nick Viall', 'Ben Higgins', 'Jared Haibon',
#         'Joe Bailey', 'Chris Strandburg', 'Ben Zorn', 'Tanner Tolbert',
#         'John "J.J." Lane III', 'Joshua Albers', 'Justin Reich',
#         'Ian Thomson', 'Corey Stansell', 'Jonathan Holloway',
#         'Ryan Beckett', 'Clint Arlis', 'Tony Harris', 'Cory Shivar',
#         'Daniel Finney', 'Kupah James', 'Bradley Cox', 'David',
#         'Josh Seiter', 'Shawn Evans', 'Brady Toops', 'Ryan McDill'],
#        dtype=object),
#  array(['Shawn Booth', 'Nick Viall', 'Ben Higgins', 'Jared Haibon',
#         'Joe Bailey', 'Chris Strandburg', 'Ben Zorn', 'Tanner Tolbert',
#         'John "J.J." Lane III', 'Joshua Albers', 'Justin Reich',
#         'Ian Thomson', 'Corey Stansell', 'Jonathan Holloway',
#         'Ryan Beckett', 'Clint Arlis', 'Tony Harris', 'Cory Shivar',
#         'Daniel Finney', 'Kupah James', 'Bradley Cox', 'David',
#         'Josh Seiter', 'Shawn Evans', 'Brady Toops', 'Ryan McDill'],
#        dtype=object),
#  array(['Shawn Booth', 'Nick Viall', 'Ben Higgins', 'Jared Haibon',
#         'Joe Bailey', 'Chris Strandburg', 'Ben Zorn', 'Tanner Tolbert',
#         'John "J.J." Lane III', 'Joshua Albers', 'Justin Reich',
#         'Ian Thomson', 'Corey Stansell', 'Jonathan Holloway',
#         'Ryan Beckett', 'Clint Arlis', 'Tony Harris', 'Cory Shivar',
#         'Daniel Finney', 'Kupah James', 'Bradley Cox', 'David',
#         'Josh Seiter', 'Shawn Evans', 'Brady Toops', 'Ryan McDill'],
#        dtype=object),
#  array(['Shawn Booth', 'Nick Viall', 'Ben Higgins', 'Jared Haibon',
#         'Joe Bailey', 'Chris Strandburg', 'Ben Zorn', 'Tanner Tolbert',
#         'John "J.J." Lane III', 'Joshua Albers', 'Justin Reich',
#         'Ian Thomson', 'Corey Stansell', 'Jonathan Holloway',
#         'Ryan Beckett', 'Clint Arlis', 'Tony Harris', 'Cory Shivar',
#         'Daniel Finney', 'Kupah James', 'Bradley Cox', 'David',
#         'Josh Seiter', 'Shawn Evans', 'Brady Toops', 'Ryan McDill'],
#        dtype=object),
#  array(['Shawn Booth', 'Nick Viall', 'Ben Higgins', 'Jared Haibon',
#         'Joe Bailey', 'Chris Strandburg', 'Ben Zorn', 'Tanner Tolbert',
#         'John "J.J." Lane III', 'Joshua Albers', 'Justin Reich',
#         'Ian Thomson', 'Corey Stansell', 'Jonathan Holloway',
#         'Ryan Beckett', 'Clint Arlis', 'Tony Harris', 'Cory Shivar',
#         'Daniel Finney', 'Kupah James', 'Bradley Cox', 'David',
#         'Josh Seiter', 'Shawn Evans', 'Brady Toops', 'Ryan McDill'],
#        dtype=object),
#  array(['Shawn Booth', 'Nick Viall', 'Ben Higgins', 'Jared Haibon',
#         'Joe Bailey', 'Chris Strandburg', 'Ben Zorn', 'Tanner Tolbert',
#         'John "J.J." Lane III', 'Joshua Albers', 'Justin Reich',
#         'Ian Thomson', 'Corey Stansell', 'Jonathan Holloway',
#         'Ryan Beckett', 'Clint Arlis', 'Tony Harris', 'Cory Shivar',
#         'Daniel Finney', 'Kupah James', 'Bradley Cox', 'David',
#         'Josh Seiter', 'Shawn Evans', 'Brady Toops', 'Ryan McDill'],
#        dtype=object),
#  array(['Shawn Booth', 'Nick Viall', 'Ben Higgins', 'Jared Haibon',
#         'Joe Bailey', 'Chris Strandburg', 'Ben Zorn', 'Tanner Tolbert',
#         'John "J.J." Lane III', 'Joshua Albers', 'Justin Reich',
#         'Ian Thomson', 'Corey Stansell', 'Jonathan Holloway',
#         'Ryan Beckett', 'Clint Arlis', 'Tony Harris', 'Cory Shivar',
#         'Daniel Finney', 'Kupah James', 'Bradley Cox', 'David',
#         'Josh Seiter', 'Shawn Evans', 'Brady Toops', 'Ryan McDill'],
#        dtype=object),
#  array(['Shawn Booth', 'Nick Viall', 'Ben Higgins', 'Jared Haibon',
#         'Joe Bailey', 'Chris Strandburg', 'Ben Zorn', 'Tanner Tolbert',
#         'John "J.J." Lane III', 'Joshua Albers', 'Justin Reich',
#         'Ian Thomson', 'Corey Stansell', 'Jonathan Holloway',
#         'Ryan Beckett', 'Clint Arlis', 'Tony Harris', 'Cory Shivar',
#         'Daniel Finney', 'Kupah James', 'Bradley Cox', 'David',
#         'Josh Seiter', 'Shawn Evans', 'Brady Toops', 'Ryan McDill'],
#        dtype=object),
#  array(['Shawn Booth', 'Nick Viall', 'Ben Higgins', 'Jared Haibon',
#         'Joe Bailey', 'Chris Strandburg', 'Ben Zorn', 'Tanner Tolbert',
#         'John "J.J." Lane III', 'Joshua Albers', 'Justin Reich',
#         'Ian Thomson', 'Corey Stansell', 'Jonathan Holloway',
#         'Ryan Beckett', 'Clint Arlis', 'Tony Harris', 'Cory Shivar',
#         'Daniel Finney', 'Kupah James', 'Bradley Cox', 'David',
#         'Josh Seiter', 'Shawn Evans', 'Brady Toops', 'Ryan McDill'],
#        dtype=object),
#  array(['Jordan Rodgers', 'Robert "Robby" Hayes', 'Chase McNary',
#         'Luke Pell', 'James Taylor', 'Alexander "Alex" Woytkiw',
#         'Derek Peth', 'Wells Adams', 'Evan Bass', 'Grant Kemp',
#         'Vincent "Vinny" Ventiera', 'Daniel Maguire', 'James Fuertes',
#         'Brian "Chad" Johnson', 'Ali Zahiri', 'Christian Bishop',
#         'Nicholas "Nick" Benvenutti', 'Brandon Howell', 'James Spadafore',
#         'William "Will" Haduch', 'Colin "Coley" Knust', 'Jake Patton',
#         'Jonathan Hamilton', 'Nicholas "Nick" Sharp', 'Peter Medina',
#         'Salvatore "Sal" DeJulio'], dtype=object),
#  array(['Jordan Rodgers', 'Robert "Robby" Hayes', 'Chase McNary',
#         'Luke Pell', 'James Taylor', 'Alexander "Alex" Woytkiw',
#         'Derek Peth', 'Wells Adams', 'Evan Bass', 'Grant Kemp',
#         'Vincent "Vinny" Ventiera', 'Daniel Maguire', 'James Fuertes',
#         'Brian "Chad" Johnson', 'Ali Zahiri', 'Christian Bishop',
#         'Nicholas "Nick" Benvenutti', 'Brandon Howell', 'James Spadafore',
#         'William "Will" Haduch', 'Colin "Coley" Knust', 'Jake Patton',
#         'Jonathan Hamilton', 'Nicholas "Nick" Sharp', 'Peter Medina',
#         'Salvatore "Sal" DeJulio'], dtype=object),
#  array(['Jordan Rodgers', 'Robert "Robby" Hayes', 'Chase McNary',
#         'Luke Pell', 'James Taylor', 'Alexander "Alex" Woytkiw',
#         'Derek Peth', 'Wells Adams', 'Evan Bass', 'Grant Kemp',
#         'Vincent "Vinny" Ventiera', 'Daniel Maguire', 'James Fuertes',
#         'Brian "Chad" Johnson', 'Ali Zahiri', 'Christian Bishop',
#         'Nicholas "Nick" Benvenutti', 'Brandon Howell', 'James Spadafore',
#         'William "Will" Haduch', 'Colin "Coley" Knust', 'Jake Patton',
#         'Jonathan Hamilton', 'Nicholas "Nick" Sharp', 'Peter Medina',
#         'Salvatore "Sal" DeJulio'], dtype=object),
#  array(['Jordan Rodgers', 'Robert "Robby" Hayes', 'Chase McNary',
#         'Luke Pell', 'James Taylor', 'Alexander "Alex" Woytkiw',
#         'Derek Peth', 'Wells Adams', 'Evan Bass', 'Grant Kemp',
#         'Vincent "Vinny" Ventiera', 'Daniel Maguire', 'James Fuertes',
#         'Brian "Chad" Johnson', 'Ali Zahiri', 'Christian Bishop',
#         'Nicholas "Nick" Benvenutti', 'Brandon Howell', 'James Spadafore',
#         'William "Will" Haduch', 'Colin "Coley" Knust', 'Jake Patton',
#         'Jonathan Hamilton', 'Nicholas "Nick" Sharp', 'Peter Medina',
#         'Salvatore "Sal" DeJulio'], dtype=object),
#  array(['Jordan Rodgers', 'Robert "Robby" Hayes', 'Chase McNary',
#         'Luke Pell', 'James Taylor', 'Alexander "Alex" Woytkiw',
#         'Derek Peth', 'Wells Adams', 'Evan Bass', 'Grant Kemp',
#         'Vincent "Vinny" Ventiera', 'Daniel Maguire', 'James Fuertes',
#         'Brian "Chad" Johnson', 'Ali Zahiri', 'Christian Bishop',
#         'Nicholas "Nick" Benvenutti', 'Brandon Howell', 'James Spadafore',
#         'William "Will" Haduch', 'Colin "Coley" Knust', 'Jake Patton',
#         'Jonathan Hamilton', 'Nicholas "Nick" Sharp', 'Peter Medina',
#         'Salvatore "Sal" DeJulio'], dtype=object),
#  array(['Jordan Rodgers', 'Robert "Robby" Hayes', 'Chase McNary',
#         'Luke Pell', 'James Taylor', 'Alexander "Alex" Woytkiw',
#         'Derek Peth', 'Wells Adams', 'Evan Bass', 'Grant Kemp',
#         'Vincent "Vinny" Ventiera', 'Daniel Maguire', 'James Fuertes',
#         'Brian "Chad" Johnson', 'Ali Zahiri', 'Christian Bishop',
#         'Nicholas "Nick" Benvenutti', 'Brandon Howell', 'James Spadafore',
#         'William "Will" Haduch', 'Colin "Coley" Knust', 'Jake Patton',
#         'Jonathan Hamilton', 'Nicholas "Nick" Sharp', 'Peter Medina',
#         'Salvatore "Sal" DeJulio'], dtype=object),
#  array(['Jordan Rodgers', 'Robert "Robby" Hayes', 'Chase McNary',
#         'Luke Pell', 'James Taylor', 'Alexander "Alex" Woytkiw',
#         'Derek Peth', 'Wells Adams', 'Evan Bass', 'Grant Kemp',
#         'Vincent "Vinny" Ventiera', 'Daniel Maguire', 'James Fuertes',
#         'Brian "Chad" Johnson', 'Ali Zahiri', 'Christian Bishop',
#         'Nicholas "Nick" Benvenutti', 'Brandon Howell', 'James Spadafore',
#         'William "Will" Haduch', 'Colin "Coley" Knust', 'Jake Patton',
#         'Jonathan Hamilton', 'Nicholas "Nick" Sharp', 'Peter Medina',
#         'Salvatore "Sal" DeJulio'], dtype=object),
#  array(['Jordan Rodgers', 'Robert "Robby" Hayes', 'Chase McNary',
#         'Luke Pell', 'James Taylor', 'Alexander "Alex" Woytkiw',
#         'Derek Peth', 'Wells Adams', 'Evan Bass', 'Grant Kemp',
#         'Vincent "Vinny" Ventiera', 'Daniel Maguire', 'James Fuertes',
#         'Brian "Chad" Johnson', 'Ali Zahiri', 'Christian Bishop',
#         'Nicholas "Nick" Benvenutti', 'Brandon Howell', 'James Spadafore',
#         'William "Will" Haduch', 'Colin "Coley" Knust', 'Jake Patton',
#         'Jonathan Hamilton', 'Nicholas "Nick" Sharp', 'Peter Medina',
#         'Salvatore "Sal" DeJulio'], dtype=object),
#  array(['Jordan Rodgers', 'Robert "Robby" Hayes', 'Chase McNary',
#         'Luke Pell', 'James Taylor', 'Alexander "Alex" Woytkiw',
#         'Derek Peth', 'Wells Adams', 'Evan Bass', 'Grant Kemp',
#         'Vincent "Vinny" Ventiera', 'Daniel Maguire', 'James Fuertes',
#         'Brian "Chad" Johnson', 'Ali Zahiri', 'Christian Bishop',
#         'Nicholas "Nick" Benvenutti', 'Brandon Howell', 'James Spadafore',
#         'William "Will" Haduch', 'Colin "Coley" Knust', 'Jake Patton',
#         'Jonathan Hamilton', 'Nicholas "Nick" Sharp', 'Peter Medina',
#         'Salvatore "Sal" DeJulio'], dtype=object),
#  array(['Jordan Rodgers', 'Robert "Robby" Hayes', 'Chase McNary',
#         'Luke Pell', 'James Taylor', 'Alexander "Alex" Woytkiw',
#         'Derek Peth', 'Wells Adams', 'Evan Bass', 'Grant Kemp',
#         'Vincent "Vinny" Ventiera', 'Daniel Maguire', 'James Fuertes',
#         'Brian "Chad" Johnson', 'Ali Zahiri', 'Christian Bishop',
#         'Nicholas "Nick" Benvenutti', 'Brandon Howell', 'James Spadafore',
#         'William "Will" Haduch', 'Colin "Coley" Knust', 'Jake Patton',
#         'Jonathan Hamilton', 'Nicholas "Nick" Sharp', 'Peter Medina',
#         'Salvatore "Sal" DeJulio'], dtype=object),
#  array(['Jordan Rodgers', 'Robert "Robby" Hayes', 'Chase McNary',
#         'Luke Pell', 'James Taylor', 'Alexander "Alex" Woytkiw',
#         'Derek Peth', 'Wells Adams', 'Evan Bass', 'Grant Kemp',
#         'Vincent "Vinny" Ventiera', 'Daniel Maguire', 'James Fuertes',
#         'Brian "Chad" Johnson', 'Ali Zahiri', 'Christian Bishop',
#         'Nicholas "Nick" Benvenutti', 'Brandon Howell', 'James Spadafore',
#         'William "Will" Haduch', 'Colin "Coley" Knust', 'Jake Patton',
#         'Jonathan Hamilton', 'Nicholas "Nick" Sharp', 'Peter Medina',
#         'Salvatore "Sal" DeJulio'], dtype=object),
#  array(['Jordan Rodgers', 'Robert "Robby" Hayes', 'Chase McNary',
#         'Luke Pell', 'James Taylor', 'Alexander "Alex" Woytkiw',
#         'Derek Peth', 'Wells Adams', 'Evan Bass', 'Grant Kemp',
#         'Vincent "Vinny" Ventiera', 'Daniel Maguire', 'James Fuertes',
#         'Brian "Chad" Johnson', 'Ali Zahiri', 'Christian Bishop',
#         'Nicholas "Nick" Benvenutti', 'Brandon Howell', 'James Spadafore',
#         'William "Will" Haduch', 'Colin "Coley" Knust', 'Jake Patton',
#         'Jonathan Hamilton', 'Nicholas "Nick" Sharp', 'Peter Medina',
#         'Salvatore "Sal" DeJulio'], dtype=object),
#  array(['Bryan Abasolo', 'Peter Kraus ', 'Eric Bigger', 'Dean Unglert',
#         'Adam Gottschalk', 'Matthew "Matt" Munson',
#         'Aleksandr "Alex" Bordyukov', 'William "Will" Gaskins',
#         'Kenny Layne', 'Anthony Battle', 'Josiah Graham', 'Lee Garrett',
#         'Ignacio "Iggy" Rodriguez', 'Jonathan Treece', 'Jack Stone',
#         'Brady Ervin', 'Kenneth "Diggy" Moreland', 'Bryce Powers',
#         'Frederick "Fred" Johnson', 'Blake Elarbee', 'James "Jamey" Kocan',
#         'Lucas Yancey', 'DeMario Jackson', 'Jedidiah Ballard',
#         'Michael Black', 'Robert "Rob" Howard', 'Grant Hubsher',
#         'Blake Killpack', 'Milton LaCroix', 'Mohit Sehgal',
#         'Kyle Sherwood'], dtype=object),
#  array(['Bryan Abasolo', 'Peter Kraus ', 'Eric Bigger', 'Dean Unglert',
#         'Adam Gottschalk', 'Matthew "Matt" Munson',
#         'Aleksandr "Alex" Bordyukov', 'William "Will" Gaskins',
#         'Kenny Layne', 'Anthony Battle', 'Josiah Graham', 'Lee Garrett',
#         'Ignacio "Iggy" Rodriguez', 'Jonathan Treece', 'Jack Stone',
#         'Brady Ervin', 'Kenneth "Diggy" Moreland', 'Bryce Powers',
#         'Frederick "Fred" Johnson', 'Blake Elarbee', 'James "Jamey" Kocan',
#         'Lucas Yancey', 'DeMario Jackson', 'Jedidiah Ballard',
#         'Michael Black', 'Robert "Rob" Howard', 'Grant Hubsher',
#         'Blake Killpack', 'Milton LaCroix', 'Mohit Sehgal',
#         'Kyle Sherwood'], dtype=object),
#  array(['Bryan Abasolo', 'Peter Kraus ', 'Eric Bigger', 'Dean Unglert',
#         'Adam Gottschalk', 'Matthew "Matt" Munson',
#         'Aleksandr "Alex" Bordyukov', 'William "Will" Gaskins',
#         'Kenny Layne', 'Anthony Battle', 'Josiah Graham', 'Lee Garrett',
#         'Ignacio "Iggy" Rodriguez', 'Jonathan Treece', 'Jack Stone',
#         'Brady Ervin', 'Kenneth "Diggy" Moreland', 'Bryce Powers',
#         'Frederick "Fred" Johnson', 'Blake Elarbee', 'James "Jamey" Kocan',
#         'Lucas Yancey', 'DeMario Jackson', 'Jedidiah Ballard',
#         'Michael Black', 'Robert "Rob" Howard', 'Grant Hubsher',
#         'Blake Killpack', 'Milton LaCroix', 'Mohit Sehgal',
#         'Kyle Sherwood'], dtype=object),
#  array(['Bryan Abasolo', 'Peter Kraus ', 'Eric Bigger', 'Dean Unglert',
#         'Adam Gottschalk', 'Matthew "Matt" Munson',
#         'Aleksandr "Alex" Bordyukov', 'William "Will" Gaskins',
#         'Kenny Layne', 'Anthony Battle', 'Josiah Graham', 'Lee Garrett',
#         'Ignacio "Iggy" Rodriguez', 'Jonathan Treece', 'Jack Stone',
#         'Brady Ervin', 'Kenneth "Diggy" Moreland', 'Bryce Powers',
#         'Frederick "Fred" Johnson', 'Blake Elarbee', 'James "Jamey" Kocan',
#         'Lucas Yancey', 'DeMario Jackson', 'Jedidiah Ballard',
#         'Michael Black', 'Robert "Rob" Howard', 'Grant Hubsher',
#         'Blake Killpack', 'Milton LaCroix', 'Mohit Sehgal',
#         'Kyle Sherwood'], dtype=object),
#  array(['Bryan Abasolo', 'Peter Kraus ', 'Eric Bigger', 'Dean Unglert',
#         'Adam Gottschalk', 'Matthew "Matt" Munson',
#         'Aleksandr "Alex" Bordyukov', 'William "Will" Gaskins',
#         'Kenny Layne', 'Anthony Battle', 'Josiah Graham', 'Lee Garrett',
#         'Ignacio "Iggy" Rodriguez', 'Jonathan Treece', 'Jack Stone',
#         'Brady Ervin', 'Kenneth "Diggy" Moreland', 'Bryce Powers',
#         'Frederick "Fred" Johnson', 'Blake Elarbee', 'James "Jamey" Kocan',
#         'Lucas Yancey', 'DeMario Jackson', 'Jedidiah Ballard',
#         'Michael Black', 'Robert "Rob" Howard', 'Grant Hubsher',
#         'Blake Killpack', 'Milton LaCroix', 'Mohit Sehgal',
#         'Kyle Sherwood'], dtype=object),
#  array(['Bryan Abasolo', 'Peter Kraus ', 'Eric Bigger', 'Dean Unglert',
#         'Adam Gottschalk', 'Matthew "Matt" Munson',
#         'Aleksandr "Alex" Bordyukov', 'William "Will" Gaskins',
#         'Kenny Layne', 'Anthony Battle', 'Josiah Graham', 'Lee Garrett',
#         'Ignacio "Iggy" Rodriguez', 'Jonathan Treece', 'Jack Stone',
#         'Brady Ervin', 'Kenneth "Diggy" Moreland', 'Bryce Powers',
#         'Frederick "Fred" Johnson', 'Blake Elarbee', 'James "Jamey" Kocan',
#         'Lucas Yancey', 'DeMario Jackson', 'Jedidiah Ballard',
#         'Michael Black', 'Robert "Rob" Howard', 'Grant Hubsher',
#         'Blake Killpack', 'Milton LaCroix', 'Mohit Sehgal',
#         'Kyle Sherwood'], dtype=object),
#  array(['Bryan Abasolo', 'Peter Kraus ', 'Eric Bigger', 'Dean Unglert',
#         'Adam Gottschalk', 'Matthew "Matt" Munson',
#         'Aleksandr "Alex" Bordyukov', 'William "Will" Gaskins',
#         'Kenny Layne', 'Anthony Battle', 'Josiah Graham', 'Lee Garrett',
#         'Ignacio "Iggy" Rodriguez', 'Jonathan Treece', 'Jack Stone',
#         'Brady Ervin', 'Kenneth "Diggy" Moreland', 'Bryce Powers',
#         'Frederick "Fred" Johnson', 'Blake Elarbee', 'James "Jamey" Kocan',
#         'Lucas Yancey', 'DeMario Jackson', 'Jedidiah Ballard',
#         'Michael Black', 'Robert "Rob" Howard', 'Grant Hubsher',
#         'Blake Killpack', 'Milton LaCroix', 'Mohit Sehgal',
#         'Kyle Sherwood'], dtype=object),
#  array(['Bryan Abasolo', 'Peter Kraus ', 'Eric Bigger', 'Dean Unglert',
#         'Adam Gottschalk', 'Matthew "Matt" Munson',
#         'Aleksandr "Alex" Bordyukov', 'William "Will" Gaskins',
#         'Kenny Layne', 'Anthony Battle', 'Josiah Graham', 'Lee Garrett',
#         'Ignacio "Iggy" Rodriguez', 'Jonathan Treece', 'Jack Stone',
#         'Brady Ervin', 'Kenneth "Diggy" Moreland', 'Bryce Powers',
#         'Frederick "Fred" Johnson', 'Blake Elarbee', 'James "Jamey" Kocan',
#         'Lucas Yancey', 'DeMario Jackson', 'Jedidiah Ballard',
#         'Michael Black', 'Robert "Rob" Howard', 'Grant Hubsher',
#         'Blake Killpack', 'Milton LaCroix', 'Mohit Sehgal',
#         'Kyle Sherwood'], dtype=object),
#  array(['Bryan Abasolo', 'Peter Kraus ', 'Eric Bigger', 'Dean Unglert',
#         'Adam Gottschalk', 'Matthew "Matt" Munson',
#         'Aleksandr "Alex" Bordyukov', 'William "Will" Gaskins',
#         'Kenny Layne', 'Anthony Battle', 'Josiah Graham', 'Lee Garrett',
#         'Ignacio "Iggy" Rodriguez', 'Jonathan Treece', 'Jack Stone',
#         'Brady Ervin', 'Kenneth "Diggy" Moreland', 'Bryce Powers',
#         'Frederick "Fred" Johnson', 'Blake Elarbee', 'James "Jamey" Kocan',
#         'Lucas Yancey', 'DeMario Jackson', 'Jedidiah Ballard',
#         'Michael Black', 'Robert "Rob" Howard', 'Grant Hubsher',
#         'Blake Killpack', 'Milton LaCroix', 'Mohit Sehgal',
#         'Kyle Sherwood'], dtype=object),
#  array(['Bryan Abasolo', 'Peter Kraus ', 'Eric Bigger', 'Dean Unglert',
#         'Adam Gottschalk', 'Matthew "Matt" Munson',
#         'Aleksandr "Alex" Bordyukov', 'William "Will" Gaskins',
#         'Kenny Layne', 'Anthony Battle', 'Josiah Graham', 'Lee Garrett',
#         'Ignacio "Iggy" Rodriguez', 'Jonathan Treece', 'Jack Stone',
#         'Brady Ervin', 'Kenneth "Diggy" Moreland', 'Bryce Powers',
#         'Frederick "Fred" Johnson', 'Blake Elarbee', 'James "Jamey" Kocan',
#         'Lucas Yancey', 'DeMario Jackson', 'Jedidiah Ballard',
#         'Michael Black', 'Robert "Rob" Howard', 'Grant Hubsher',
#         'Blake Killpack', 'Milton LaCroix', 'Mohit Sehgal',
#         'Kyle Sherwood'], dtype=object),
#  array(['Bryan Abasolo', 'Peter Kraus ', 'Eric Bigger', 'Dean Unglert',
#         'Adam Gottschalk', 'Matthew "Matt" Munson',
#         'Aleksandr "Alex" Bordyukov', 'William "Will" Gaskins',
#         'Kenny Layne', 'Anthony Battle', 'Josiah Graham', 'Lee Garrett',
#         'Ignacio "Iggy" Rodriguez', 'Jonathan Treece', 'Jack Stone',
#         'Brady Ervin', 'Kenneth "Diggy" Moreland', 'Bryce Powers',
#         'Frederick "Fred" Johnson', 'Blake Elarbee', 'James "Jamey" Kocan',
#         'Lucas Yancey', 'DeMario Jackson', 'Jedidiah Ballard',
#         'Michael Black', 'Robert "Rob" Howard', 'Grant Hubsher',
#         'Blake Killpack', 'Milton LaCroix', 'Mohit Sehgal',
#         'Kyle Sherwood'], dtype=object),
#  array(['Garrett Yrigoyen', 'Blake Horstmann', 'Jason Tartick',
#         'Colton Underwood', 'William "Wills" Reid',
#         'Leandro "Leo" Dottavio', 'Connor Obrochta', 'Lincoln Adim',
#         'Chris Randone', 'John Graham', 'Jordan Kimball', 'David Ravitz',
#         'Christon Staples', 'Nicholas "Nick" Spetsas', 'Jean Blanc',
#         'Michael "Mike" Renner', 'Ryan Peterson', 'Clay Harbor',
#         'Alex Templeman', 'Rickey Jasper', 'Trent Jespersen',
#         'Chase Vergason', 'Christian Estrada', 'Darius Feaster',
#         'Grant Vandevanter', 'Joe Amabile', 'Kamil Nicalek',
#         'Jake Enyeart'], dtype=object),
#  array(['Garrett Yrigoyen', 'Blake Horstmann', 'Jason Tartick',
#         'Colton Underwood', 'William "Wills" Reid',
#         'Leandro "Leo" Dottavio', 'Connor Obrochta', 'Lincoln Adim',
#         'Chris Randone', 'John Graham', 'Jordan Kimball', 'David Ravitz',
#         'Christon Staples', 'Nicholas "Nick" Spetsas', 'Jean Blanc',
#         'Michael "Mike" Renner', 'Ryan Peterson', 'Clay Harbor',
#         'Alex Templeman', 'Rickey Jasper', 'Trent Jespersen',
#         'Chase Vergason', 'Christian Estrada', 'Darius Feaster',
#         'Grant Vandevanter', 'Joe Amabile', 'Kamil Nicalek',
#         'Jake Enyeart'], dtype=object),
#  array(['Garrett Yrigoyen', 'Blake Horstmann', 'Jason Tartick',
#         'Colton Underwood', 'William "Wills" Reid',
#         'Leandro "Leo" Dottavio', 'Connor Obrochta', 'Lincoln Adim',
#         'Chris Randone', 'John Graham', 'Jordan Kimball', 'David Ravitz',
#         'Christon Staples', 'Nicholas "Nick" Spetsas', 'Jean Blanc',
#         'Michael "Mike" Renner', 'Ryan Peterson', 'Clay Harbor',
#         'Alex Templeman', 'Rickey Jasper', 'Trent Jespersen',
#         'Chase Vergason', 'Christian Estrada', 'Darius Feaster',
#         'Grant Vandevanter', 'Joe Amabile', 'Kamil Nicalek',
#         'Jake Enyeart'], dtype=object),
#  array(['Garrett Yrigoyen', 'Blake Horstmann', 'Jason Tartick',
#         'Colton Underwood', 'William "Wills" Reid',
#         'Leandro "Leo" Dottavio', 'Connor Obrochta', 'Lincoln Adim',
#         'Chris Randone', 'John Graham', 'Jordan Kimball', 'David Ravitz',
#         'Christon Staples', 'Nicholas "Nick" Spetsas', 'Jean Blanc',
#         'Michael "Mike" Renner', 'Ryan Peterson', 'Clay Harbor',
#         'Alex Templeman', 'Rickey Jasper', 'Trent Jespersen',
#         'Chase Vergason', 'Christian Estrada', 'Darius Feaster',
#         'Grant Vandevanter', 'Joe Amabile', 'Kamil Nicalek',
#         'Jake Enyeart'], dtype=object),
#  array(['Garrett Yrigoyen', 'Blake Horstmann', 'Jason Tartick',
#         'Colton Underwood', 'William "Wills" Reid',
#         'Leandro "Leo" Dottavio', 'Connor Obrochta', 'Lincoln Adim',
#         'Chris Randone', 'John Graham', 'Jordan Kimball', 'David Ravitz',
#         'Christon Staples', 'Nicholas "Nick" Spetsas', 'Jean Blanc',
#         'Michael "Mike" Renner', 'Ryan Peterson', 'Clay Harbor',
#         'Alex Templeman', 'Rickey Jasper', 'Trent Jespersen',
#         'Chase Vergason', 'Christian Estrada', 'Darius Feaster',
#         'Grant Vandevanter', 'Joe Amabile', 'Kamil Nicalek',
#         'Jake Enyeart'], dtype=object),
#  array(['Garrett Yrigoyen', 'Blake Horstmann', 'Jason Tartick',
#         'Colton Underwood', 'William "Wills" Reid',
#         'Leandro "Leo" Dottavio', 'Connor Obrochta', 'Lincoln Adim',
#         'Chris Randone', 'John Graham', 'Jordan Kimball', 'David Ravitz',
#         'Christon Staples', 'Nicholas "Nick" Spetsas', 'Jean Blanc',
#         'Michael "Mike" Renner', 'Ryan Peterson', 'Clay Harbor',
#         'Alex Templeman', 'Rickey Jasper', 'Trent Jespersen',
#         'Chase Vergason', 'Christian Estrada', 'Darius Feaster',
#         'Grant Vandevanter', 'Joe Amabile', 'Kamil Nicalek',
#         'Jake Enyeart'], dtype=object),
#  array(['Garrett Yrigoyen', 'Blake Horstmann', 'Jason Tartick',
#         'Colton Underwood', 'William "Wills" Reid',
#         'Leandro "Leo" Dottavio', 'Connor Obrochta', 'Lincoln Adim',
#         'Chris Randone', 'John Graham', 'Jordan Kimball', 'David Ravitz',
#         'Christon Staples', 'Nicholas "Nick" Spetsas', 'Jean Blanc',
#         'Michael "Mike" Renner', 'Ryan Peterson', 'Clay Harbor',
#         'Alex Templeman', 'Rickey Jasper', 'Trent Jespersen',
#         'Chase Vergason', 'Christian Estrada', 'Darius Feaster',
#         'Grant Vandevanter', 'Joe Amabile', 'Kamil Nicalek',
#         'Jake Enyeart'], dtype=object),
#  array(['Garrett Yrigoyen', 'Blake Horstmann', 'Jason Tartick',
#         'Colton Underwood', 'William "Wills" Reid',
#         'Leandro "Leo" Dottavio', 'Connor Obrochta', 'Lincoln Adim',
#         'Chris Randone', 'John Graham', 'Jordan Kimball', 'David Ravitz',
#         'Christon Staples', 'Nicholas "Nick" Spetsas', 'Jean Blanc',
#         'Michael "Mike" Renner', 'Ryan Peterson', 'Clay Harbor',
#         'Alex Templeman', 'Rickey Jasper', 'Trent Jespersen',
#         'Chase Vergason', 'Christian Estrada', 'Darius Feaster',
#         'Grant Vandevanter', 'Joe Amabile', 'Kamil Nicalek',
#         'Jake Enyeart'], dtype=object),
#  array(['Garrett Yrigoyen', 'Blake Horstmann', 'Jason Tartick',
#         'Colton Underwood', 'William "Wills" Reid',
#         'Leandro "Leo" Dottavio', 'Connor Obrochta', 'Lincoln Adim',
#         'Chris Randone', 'John Graham', 'Jordan Kimball', 'David Ravitz',
#         'Christon Staples', 'Nicholas "Nick" Spetsas', 'Jean Blanc',
#         'Michael "Mike" Renner', 'Ryan Peterson', 'Clay Harbor',
#         'Alex Templeman', 'Rickey Jasper', 'Trent Jespersen',
#         'Chase Vergason', 'Christian Estrada', 'Darius Feaster',
#         'Grant Vandevanter', 'Joe Amabile', 'Kamil Nicalek',
#         'Jake Enyeart'], dtype=object),
#  array(['Garrett Yrigoyen', 'Blake Horstmann', 'Jason Tartick',
#         'Colton Underwood', 'William "Wills" Reid',
#         'Leandro "Leo" Dottavio', 'Connor Obrochta', 'Lincoln Adim',
#         'Chris Randone', 'John Graham', 'Jordan Kimball', 'David Ravitz',
#         'Christon Staples', 'Nicholas "Nick" Spetsas', 'Jean Blanc',
#         'Michael "Mike" Renner', 'Ryan Peterson', 'Clay Harbor',
#         'Alex Templeman', 'Rickey Jasper', 'Trent Jespersen',
#         'Chase Vergason', 'Christian Estrada', 'Darius Feaster',
#         'Grant Vandevanter', 'Joe Amabile', 'Kamil Nicalek',
#         'Jake Enyeart'], dtype=object),
#  array(['Garrett Yrigoyen', 'Blake Horstmann', 'Jason Tartick',
#         'Colton Underwood', 'William "Wills" Reid',
#         'Leandro "Leo" Dottavio', 'Connor Obrochta', 'Lincoln Adim',
#         'Chris Randone', 'John Graham', 'Jordan Kimball', 'David Ravitz',
#         'Christon Staples', 'Nicholas "Nick" Spetsas', 'Jean Blanc',
#         'Michael "Mike" Renner', 'Ryan Peterson', 'Clay Harbor',
#         'Alex Templeman', 'Rickey Jasper', 'Trent Jespersen',
#         'Chase Vergason', 'Christian Estrada', 'Darius Feaster',
#         'Grant Vandevanter', 'Joe Amabile', 'Kamil Nicalek',
#         'Jake Enyeart'], dtype=object),
#  array(['Jed Wyatt ', 'Tyler Cameron', 'Peter Weber', 'Luke Parker',
#         'Garrett Powell', 'Mike Johnson', 'Connor Saeli',
#         'Dustin Kendrick', 'Dylan Barbour', 'Devin Harris', 'Grant Eckel',
#         'Kevin Fortenberry', 'John Paul Jones', 'Matteo Valles',
#         'Luke Stone', 'Cameron "Cam" Ayala', 'Joey Jones',
#         'Jonathan Saunders', 'Tyler Gwozdz†', 'Connor Jenkins',
#         'Daron Blaylock', 'Matthew Spraggins', 'Brian Bowles',
#         'Chasen Coscia', 'Hunter Jones', 'Joe Barsano', 'Matt Donald',
#         'Ryan Spirko', 'Thomas Staton', 'Scott Andersen'], dtype=object),
#  array(['Jed Wyatt ', 'Tyler Cameron', 'Peter Weber', 'Luke Parker',
#         'Garrett Powell', 'Mike Johnson', 'Connor Saeli',
#         'Dustin Kendrick', 'Dylan Barbour', 'Devin Harris', 'Grant Eckel',
#         'Kevin Fortenberry', 'John Paul Jones', 'Matteo Valles',
#         'Luke Stone', 'Cameron "Cam" Ayala', 'Joey Jones',
#         'Jonathan Saunders', 'Tyler Gwozdz†', 'Connor Jenkins',
#         'Daron Blaylock', 'Matthew Spraggins', 'Brian Bowles',
#         'Chasen Coscia', 'Hunter Jones', 'Joe Barsano', 'Matt Donald',
#         'Ryan Spirko', 'Thomas Staton', 'Scott Andersen'], dtype=object),
#  array(['Jed Wyatt ', 'Tyler Cameron', 'Peter Weber', 'Luke Parker',
#         'Garrett Powell', 'Mike Johnson', 'Connor Saeli',
#         'Dustin Kendrick', 'Dylan Barbour', 'Devin Harris', 'Grant Eckel',
#         'Kevin Fortenberry', 'John Paul Jones', 'Matteo Valles',
#         'Luke Stone', 'Cameron "Cam" Ayala', 'Joey Jones',
#         'Jonathan Saunders', 'Tyler Gwozdz†', 'Connor Jenkins',
#         'Daron Blaylock', 'Matthew Spraggins', 'Brian Bowles',
#         'Chasen Coscia', 'Hunter Jones', 'Joe Barsano', 'Matt Donald',
#         'Ryan Spirko', 'Thomas Staton', 'Scott Andersen'], dtype=object),
#  array(['Jed Wyatt ', 'Tyler Cameron', 'Peter Weber', 'Luke Parker',
#         'Garrett Powell', 'Mike Johnson', 'Connor Saeli',
#         'Dustin Kendrick', 'Dylan Barbour', 'Devin Harris', 'Grant Eckel',
#         'Kevin Fortenberry', 'John Paul Jones', 'Matteo Valles',
#         'Luke Stone', 'Cameron "Cam" Ayala', 'Joey Jones',
#         'Jonathan Saunders', 'Tyler Gwozdz†', 'Connor Jenkins',
#         'Daron Blaylock', 'Matthew Spraggins', 'Brian Bowles',
#         'Chasen Coscia', 'Hunter Jones', 'Joe Barsano', 'Matt Donald',
#         'Ryan Spirko', 'Thomas Staton', 'Scott Andersen'], dtype=object),
#  array(['Jed Wyatt ', 'Tyler Cameron', 'Peter Weber', 'Luke Parker',
#         'Garrett Powell', 'Mike Johnson', 'Connor Saeli',
#         'Dustin Kendrick', 'Dylan Barbour', 'Devin Harris', 'Grant Eckel',
#         'Kevin Fortenberry', 'John Paul Jones', 'Matteo Valles',
#         'Luke Stone', 'Cameron "Cam" Ayala', 'Joey Jones',
#         'Jonathan Saunders', 'Tyler Gwozdz†', 'Connor Jenkins',
#         'Daron Blaylock', 'Matthew Spraggins', 'Brian Bowles',
#         'Chasen Coscia', 'Hunter Jones', 'Joe Barsano', 'Matt Donald',
#         'Ryan Spirko', 'Thomas Staton', 'Scott Andersen'], dtype=object),
#  array(['Jed Wyatt ', 'Tyler Cameron', 'Peter Weber', 'Luke Parker',
#         'Garrett Powell', 'Mike Johnson', 'Connor Saeli',
#         'Dustin Kendrick', 'Dylan Barbour', 'Devin Harris', 'Grant Eckel',
#         'Kevin Fortenberry', 'John Paul Jones', 'Matteo Valles',
#         'Luke Stone', 'Cameron "Cam" Ayala', 'Joey Jones',
#         'Jonathan Saunders', 'Tyler Gwozdz†', 'Connor Jenkins',
#         'Daron Blaylock', 'Matthew Spraggins', 'Brian Bowles',
#         'Chasen Coscia', 'Hunter Jones', 'Joe Barsano', 'Matt Donald',
#         'Ryan Spirko', 'Thomas Staton', 'Scott Andersen'], dtype=object),
#  array(['Jed Wyatt ', 'Tyler Cameron', 'Peter Weber', 'Luke Parker',
#         'Garrett Powell', 'Mike Johnson', 'Connor Saeli',
#         'Dustin Kendrick', 'Dylan Barbour', 'Devin Harris', 'Grant Eckel',
#         'Kevin Fortenberry', 'John Paul Jones', 'Matteo Valles',
#         'Luke Stone', 'Cameron "Cam" Ayala', 'Joey Jones',
#         'Jonathan Saunders', 'Tyler Gwozdz†', 'Connor Jenkins',
#         'Daron Blaylock', 'Matthew Spraggins', 'Brian Bowles',
#         'Chasen Coscia', 'Hunter Jones', 'Joe Barsano', 'Matt Donald',
#         'Ryan Spirko', 'Thomas Staton', 'Scott Andersen'], dtype=object),
#  array(['Jed Wyatt ', 'Tyler Cameron', 'Peter Weber', 'Luke Parker',
#         'Garrett Powell', 'Mike Johnson', 'Connor Saeli',
#         'Dustin Kendrick', 'Dylan Barbour', 'Devin Harris', 'Grant Eckel',
#         'Kevin Fortenberry', 'John Paul Jones', 'Matteo Valles',
#         'Luke Stone', 'Cameron "Cam" Ayala', 'Joey Jones',
#         'Jonathan Saunders', 'Tyler Gwozdz†', 'Connor Jenkins',
#         'Daron Blaylock', 'Matthew Spraggins', 'Brian Bowles',
#         'Chasen Coscia', 'Hunter Jones', 'Joe Barsano', 'Matt Donald',
#         'Ryan Spirko', 'Thomas Staton', 'Scott Andersen'], dtype=object),
#  array(['Jed Wyatt ', 'Tyler Cameron', 'Peter Weber', 'Luke Parker',
#         'Garrett Powell', 'Mike Johnson', 'Connor Saeli',
#         'Dustin Kendrick', 'Dylan Barbour', 'Devin Harris', 'Grant Eckel',
#         'Kevin Fortenberry', 'John Paul Jones', 'Matteo Valles',
#         'Luke Stone', 'Cameron "Cam" Ayala', 'Joey Jones',
#         'Jonathan Saunders', 'Tyler Gwozdz†', 'Connor Jenkins',
#         'Daron Blaylock', 'Matthew Spraggins', 'Brian Bowles',
#         'Chasen Coscia', 'Hunter Jones', 'Joe Barsano', 'Matt Donald',
#         'Ryan Spirko', 'Thomas Staton', 'Scott Andersen'], dtype=object),
#  array(['Jed Wyatt ', 'Tyler Cameron', 'Peter Weber', 'Luke Parker',
#         'Garrett Powell', 'Mike Johnson', 'Connor Saeli',
#         'Dustin Kendrick', 'Dylan Barbour', 'Devin Harris', 'Grant Eckel',
#         'Kevin Fortenberry', 'John Paul Jones', 'Matteo Valles',
#         'Luke Stone', 'Cameron "Cam" Ayala', 'Joey Jones',
#         'Jonathan Saunders', 'Tyler Gwozdz†', 'Connor Jenkins',
#         'Daron Blaylock', 'Matthew Spraggins', 'Brian Bowles',
#         'Chasen Coscia', 'Hunter Jones', 'Joe Barsano', 'Matt Donald',
#         'Ryan Spirko', 'Thomas Staton', 'Scott Andersen'], dtype=object),
#  array(['Jed Wyatt ', 'Tyler Cameron', 'Peter Weber', 'Luke Parker',
#         'Garrett Powell', 'Mike Johnson', 'Connor Saeli',
#         'Dustin Kendrick', 'Dylan Barbour', 'Devin Harris', 'Grant Eckel',
#         'Kevin Fortenberry', 'John Paul Jones', 'Matteo Valles',
#         'Luke Stone', 'Cameron "Cam" Ayala', 'Joey Jones',
#         'Jonathan Saunders', 'Tyler Gwozdz†', 'Connor Jenkins',
#         'Daron Blaylock', 'Matthew Spraggins', 'Brian Bowles',
#         'Chasen Coscia', 'Hunter Jones', 'Joe Barsano', 'Matt Donald',
#         'Ryan Spirko', 'Thomas Staton', 'Scott Andersen'], dtype=object),
#  array(['Jed Wyatt ', 'Tyler Cameron', 'Peter Weber', 'Luke Parker',
#         'Garrett Powell', 'Mike Johnson', 'Connor Saeli',
#         'Dustin Kendrick', 'Dylan Barbour', 'Devin Harris', 'Grant Eckel',
#         'Kevin Fortenberry', 'John Paul Jones', 'Matteo Valles',
#         'Luke Stone', 'Cameron "Cam" Ayala', 'Joey Jones',
#         'Jonathan Saunders', 'Tyler Gwozdz†', 'Connor Jenkins',
#         'Daron Blaylock', 'Matthew Spraggins', 'Brian Bowles',
#         'Chasen Coscia', 'Hunter Jones', 'Joe Barsano', 'Matt Donald',
#         'Ryan Spirko', 'Thomas Staton', 'Scott Andersen'], dtype=object),
#  array(['Jed Wyatt ', 'Tyler Cameron', 'Peter Weber', 'Luke Parker',
#         'Garrett Powell', 'Mike Johnson', 'Connor Saeli',
#         'Dustin Kendrick', 'Dylan Barbour', 'Devin Harris', 'Grant Eckel',
#         'Kevin Fortenberry', 'John Paul Jones', 'Matteo Valles',
# ...
#         'Yosef Aborady', 'Brandon Goss', 'AJ Yalawan', 'Chris Conran',
#         'Jeremy Higgins', 'Jordan Manier', 'Mike Tobin', 'Page Pressley',
#         'Robby Stahl', 'Tyler Cottrill', 'Week 1'], dtype=object),
#  array(['Dale Moss', 'Zac Clark', 'Ben Smith', 'Ivan Hall',
#         'Brendan Morais', 'Bennett Jordan', 'Noah Erb', 'Riley Christian',
#         'Blake Moynes', 'Demar Jackson', 'Ed Waisbrot',
#         'Spencer Robertson', 'Uzoma "Eazy" Nwachukwu', 'Chasen Nick',
#         'Joe Park', 'Jordan Chapman', 'Kenny Braasch', 'Jay Smith',
#         'Montel Hill', 'Peter Giannikopoulos', 'Jason Foster',
#         'Zach Jackson', 'Blake Monar', 'Garin Flowers', 'Tyler Smith',
#         'Yosef Aborady', 'Brandon Goss', 'AJ Yalawan', 'Chris Conran',
#         'Jeremy Higgins', 'Jordan Manier', 'Mike Tobin', 'Page Pressley',
#         'Robby Stahl', 'Tyler Cottrill', 'Week 1'], dtype=object),
#  array(['Dale Moss', 'Zac Clark', 'Ben Smith', 'Ivan Hall',
#         'Brendan Morais', 'Bennett Jordan', 'Noah Erb', 'Riley Christian',
#         'Blake Moynes', 'Demar Jackson', 'Ed Waisbrot',
#         'Spencer Robertson', 'Uzoma "Eazy" Nwachukwu', 'Chasen Nick',
#         'Joe Park', 'Jordan Chapman', 'Kenny Braasch', 'Jay Smith',
#         'Montel Hill', 'Peter Giannikopoulos', 'Jason Foster',
#         'Zach Jackson', 'Blake Monar', 'Garin Flowers', 'Tyler Smith',
#         'Yosef Aborady', 'Brandon Goss', 'AJ Yalawan', 'Chris Conran',
#         'Jeremy Higgins', 'Jordan Manier', 'Mike Tobin', 'Page Pressley',
#         'Robby Stahl', 'Tyler Cottrill', 'Week 1'], dtype=object),
#  array(['Dale Moss', 'Zac Clark', 'Ben Smith', 'Ivan Hall',
#         'Brendan Morais', 'Bennett Jordan', 'Noah Erb', 'Riley Christian',
#         'Blake Moynes', 'Demar Jackson', 'Ed Waisbrot',
#         'Spencer Robertson', 'Uzoma "Eazy" Nwachukwu', 'Chasen Nick',
#         'Joe Park', 'Jordan Chapman', 'Kenny Braasch', 'Jay Smith',
#         'Montel Hill', 'Peter Giannikopoulos', 'Jason Foster',
#         'Zach Jackson', 'Blake Monar', 'Garin Flowers', 'Tyler Smith',
#         'Yosef Aborady', 'Brandon Goss', 'AJ Yalawan', 'Chris Conran',
#         'Jeremy Higgins', 'Jordan Manier', 'Mike Tobin', 'Page Pressley',
#         'Robby Stahl', 'Tyler Cottrill', 'Week 1'], dtype=object),
#  array(['Dale Moss', 'Zac Clark', 'Ben Smith', 'Ivan Hall',
#         'Brendan Morais', 'Bennett Jordan', 'Noah Erb', 'Riley Christian',
#         'Blake Moynes', 'Demar Jackson', 'Ed Waisbrot',
#         'Spencer Robertson', 'Uzoma "Eazy" Nwachukwu', 'Chasen Nick',
#         'Joe Park', 'Jordan Chapman', 'Kenny Braasch', 'Jay Smith',
#         'Montel Hill', 'Peter Giannikopoulos', 'Jason Foster',
#         'Zach Jackson', 'Blake Monar', 'Garin Flowers', 'Tyler Smith',
#         'Yosef Aborady', 'Brandon Goss', 'AJ Yalawan', 'Chris Conran',
#         'Jeremy Higgins', 'Jordan Manier', 'Mike Tobin', 'Page Pressley',
#         'Robby Stahl', 'Tyler Cottrill', 'Week 1'], dtype=object),
#  array(['Blake Moynes', 'Justin Glaze', 'Greg Grippo', 'Michael Allio',
#         'Andrew Spencer', 'Mike Planeta', 'Brendan Scanzano',
#         'Aaron Clancy', 'Hunter Montgomery', 'James Bonsall', 'Tré Cooper',
#         'Connor Brennan', 'Andrew Milcovich', 'Josh Tylerbest',
#         'Quartney Mixon', 'Christian Smith', 'Conor Costello',
#         'David Scott', 'Thomas Jacobs', 'Garrett Schwartz', 'John Hersey',
#         'Karl Smith', 'Kyle Howard', 'Cody Menk', 'Austin Tinsley',
#         'Brandon Torres', 'Gabriel Everett', 'Jeff Caravello',
#         'Landon Goesling', 'Marcus Lathan', 'Marty Hargrove', 'Week 1'],
#        dtype=object),
#  array(['Blake Moynes', 'Justin Glaze', 'Greg Grippo', 'Michael Allio',
#         'Andrew Spencer', 'Mike Planeta', 'Brendan Scanzano',
#         'Aaron Clancy', 'Hunter Montgomery', 'James Bonsall', 'Tré Cooper',
#         'Connor Brennan', 'Andrew Milcovich', 'Josh Tylerbest',
#         'Quartney Mixon', 'Christian Smith', 'Conor Costello',
#         'David Scott', 'Thomas Jacobs', 'Garrett Schwartz', 'John Hersey',
#         'Karl Smith', 'Kyle Howard', 'Cody Menk', 'Austin Tinsley',
#         'Brandon Torres', 'Gabriel Everett', 'Jeff Caravello',
#         'Landon Goesling', 'Marcus Lathan', 'Marty Hargrove', 'Week 1'],
#        dtype=object),
#  array(['Blake Moynes', 'Justin Glaze', 'Greg Grippo', 'Michael Allio',
#         'Andrew Spencer', 'Mike Planeta', 'Brendan Scanzano',
#         'Aaron Clancy', 'Hunter Montgomery', 'James Bonsall', 'Tré Cooper',
#         'Connor Brennan', 'Andrew Milcovich', 'Josh Tylerbest',
#         'Quartney Mixon', 'Christian Smith', 'Conor Costello',
#         'David Scott', 'Thomas Jacobs', 'Garrett Schwartz', 'John Hersey',
#         'Karl Smith', 'Kyle Howard', 'Cody Menk', 'Austin Tinsley',
#         'Brandon Torres', 'Gabriel Everett', 'Jeff Caravello',
#         'Landon Goesling', 'Marcus Lathan', 'Marty Hargrove', 'Week 1'],
#        dtype=object),
#  array(['Blake Moynes', 'Justin Glaze', 'Greg Grippo', 'Michael Allio',
#         'Andrew Spencer', 'Mike Planeta', 'Brendan Scanzano',
#         'Aaron Clancy', 'Hunter Montgomery', 'James Bonsall', 'Tré Cooper',
#         'Connor Brennan', 'Andrew Milcovich', 'Josh Tylerbest',
#         'Quartney Mixon', 'Christian Smith', 'Conor Costello',
#         'David Scott', 'Thomas Jacobs', 'Garrett Schwartz', 'John Hersey',
#         'Karl Smith', 'Kyle Howard', 'Cody Menk', 'Austin Tinsley',
#         'Brandon Torres', 'Gabriel Everett', 'Jeff Caravello',
#         'Landon Goesling', 'Marcus Lathan', 'Marty Hargrove', 'Week 1'],
#        dtype=object),
#  array(['Blake Moynes', 'Justin Glaze', 'Greg Grippo', 'Michael Allio',
#         'Andrew Spencer', 'Mike Planeta', 'Brendan Scanzano',
#         'Aaron Clancy', 'Hunter Montgomery', 'James Bonsall', 'Tré Cooper',
#         'Connor Brennan', 'Andrew Milcovich', 'Josh Tylerbest',
#         'Quartney Mixon', 'Christian Smith', 'Conor Costello',
#         'David Scott', 'Thomas Jacobs', 'Garrett Schwartz', 'John Hersey',
#         'Karl Smith', 'Kyle Howard', 'Cody Menk', 'Austin Tinsley',
#         'Brandon Torres', 'Gabriel Everett', 'Jeff Caravello',
#         'Landon Goesling', 'Marcus Lathan', 'Marty Hargrove', 'Week 1'],
#        dtype=object),
#  array(['Blake Moynes', 'Justin Glaze', 'Greg Grippo', 'Michael Allio',
#         'Andrew Spencer', 'Mike Planeta', 'Brendan Scanzano',
#         'Aaron Clancy', 'Hunter Montgomery', 'James Bonsall', 'Tré Cooper',
#         'Connor Brennan', 'Andrew Milcovich', 'Josh Tylerbest',
#         'Quartney Mixon', 'Christian Smith', 'Conor Costello',
#         'David Scott', 'Thomas Jacobs', 'Garrett Schwartz', 'John Hersey',
#         'Karl Smith', 'Kyle Howard', 'Cody Menk', 'Austin Tinsley',
#         'Brandon Torres', 'Gabriel Everett', 'Jeff Caravello',
#         'Landon Goesling', 'Marcus Lathan', 'Marty Hargrove', 'Week 1'],
#        dtype=object),
#  array(['Blake Moynes', 'Justin Glaze', 'Greg Grippo', 'Michael Allio',
#         'Andrew Spencer', 'Mike Planeta', 'Brendan Scanzano',
#         'Aaron Clancy', 'Hunter Montgomery', 'James Bonsall', 'Tré Cooper',
#         'Connor Brennan', 'Andrew Milcovich', 'Josh Tylerbest',
#         'Quartney Mixon', 'Christian Smith', 'Conor Costello',
#         'David Scott', 'Thomas Jacobs', 'Garrett Schwartz', 'John Hersey',
#         'Karl Smith', 'Kyle Howard', 'Cody Menk', 'Austin Tinsley',
#         'Brandon Torres', 'Gabriel Everett', 'Jeff Caravello',
#         'Landon Goesling', 'Marcus Lathan', 'Marty Hargrove', 'Week 1'],
#        dtype=object),
#  array(['Blake Moynes', 'Justin Glaze', 'Greg Grippo', 'Michael Allio',
#         'Andrew Spencer', 'Mike Planeta', 'Brendan Scanzano',
#         'Aaron Clancy', 'Hunter Montgomery', 'James Bonsall', 'Tré Cooper',
#         'Connor Brennan', 'Andrew Milcovich', 'Josh Tylerbest',
#         'Quartney Mixon', 'Christian Smith', 'Conor Costello',
#         'David Scott', 'Thomas Jacobs', 'Garrett Schwartz', 'John Hersey',
#         'Karl Smith', 'Kyle Howard', 'Cody Menk', 'Austin Tinsley',
#         'Brandon Torres', 'Gabriel Everett', 'Jeff Caravello',
#         'Landon Goesling', 'Marcus Lathan', 'Marty Hargrove', 'Week 1'],
#        dtype=object),
#  array(['Blake Moynes', 'Justin Glaze', 'Greg Grippo', 'Michael Allio',
#         'Andrew Spencer', 'Mike Planeta', 'Brendan Scanzano',
#         'Aaron Clancy', 'Hunter Montgomery', 'James Bonsall', 'Tré Cooper',
#         'Connor Brennan', 'Andrew Milcovich', 'Josh Tylerbest',
#         'Quartney Mixon', 'Christian Smith', 'Conor Costello',
#         'David Scott', 'Thomas Jacobs', 'Garrett Schwartz', 'John Hersey',
#         'Karl Smith', 'Kyle Howard', 'Cody Menk', 'Austin Tinsley',
#         'Brandon Torres', 'Gabriel Everett', 'Jeff Caravello',
#         'Landon Goesling', 'Marcus Lathan', 'Marty Hargrove', 'Week 1'],
#        dtype=object),
#  array(['Blake Moynes', 'Justin Glaze', 'Greg Grippo', 'Michael Allio',
#         'Andrew Spencer', 'Mike Planeta', 'Brendan Scanzano',
#         'Aaron Clancy', 'Hunter Montgomery', 'James Bonsall', 'Tré Cooper',
#         'Connor Brennan', 'Andrew Milcovich', 'Josh Tylerbest',
#         'Quartney Mixon', 'Christian Smith', 'Conor Costello',
#         'David Scott', 'Thomas Jacobs', 'Garrett Schwartz', 'John Hersey',
#         'Karl Smith', 'Kyle Howard', 'Cody Menk', 'Austin Tinsley',
#         'Brandon Torres', 'Gabriel Everett', 'Jeff Caravello',
#         'Landon Goesling', 'Marcus Lathan', 'Marty Hargrove', 'Week 1'],
#        dtype=object),
#  array(['Brandon Jones', 'Joe Coleman', 'Nayte Olukoya', 'Rodney Matthews',
#         'Olumide "Olu" Onajide', 'Rick Leach', 'Martin Gelbspan',
#         'Clayton Echard', 'Casey Woods', 'Leroy Arthur', 'Chris Sutton',
#         'Chris Gallant', 'Romeo Alexander', 'Will Urena',
#         'Lowell "LT" Murray IV', 'Mollique Johnson', 'Peter Izzo',
#         'Spencer Williams', 'Jamie Skaar', 'Alec Thompson', 'Daniel Tully',
#         'Pardeep Singh', 'PJ Henderson', 'Brandon Kieffer',
#         'Bryan Witzmann', 'Edward Naranjo', 'Garrett Aida', 'Jack Russell',
#         'JoMarri Gable', 'Ryan Fox'], dtype=object),
#  array(['Brandon Jones', 'Joe Coleman', 'Nayte Olukoya', 'Rodney Matthews',
#         'Olumide "Olu" Onajide', 'Rick Leach', 'Martin Gelbspan',
#         'Clayton Echard', 'Casey Woods', 'Leroy Arthur', 'Chris Sutton',
#         'Chris Gallant', 'Romeo Alexander', 'Will Urena',
#         'Lowell "LT" Murray IV', 'Mollique Johnson', 'Peter Izzo',
#         'Spencer Williams', 'Jamie Skaar', 'Alec Thompson', 'Daniel Tully',
#         'Pardeep Singh', 'PJ Henderson', 'Brandon Kieffer',
#         'Bryan Witzmann', 'Edward Naranjo', 'Garrett Aida', 'Jack Russell',
#         'JoMarri Gable', 'Ryan Fox'], dtype=object),
#  array(['Brandon Jones', 'Joe Coleman', 'Nayte Olukoya', 'Rodney Matthews',
#         'Olumide "Olu" Onajide', 'Rick Leach', 'Martin Gelbspan',
#         'Clayton Echard', 'Casey Woods', 'Leroy Arthur', 'Chris Sutton',
#         'Chris Gallant', 'Romeo Alexander', 'Will Urena',
#         'Lowell "LT" Murray IV', 'Mollique Johnson', 'Peter Izzo',
#         'Spencer Williams', 'Jamie Skaar', 'Alec Thompson', 'Daniel Tully',
#         'Pardeep Singh', 'PJ Henderson', 'Brandon Kieffer',
#         'Bryan Witzmann', 'Edward Naranjo', 'Garrett Aida', 'Jack Russell',
#         'JoMarri Gable', 'Ryan Fox'], dtype=object),
#  array(['Brandon Jones', 'Joe Coleman', 'Nayte Olukoya', 'Rodney Matthews',
#         'Olumide "Olu" Onajide', 'Rick Leach', 'Martin Gelbspan',
#         'Clayton Echard', 'Casey Woods', 'Leroy Arthur', 'Chris Sutton',
#         'Chris Gallant', 'Romeo Alexander', 'Will Urena',
#         'Lowell "LT" Murray IV', 'Mollique Johnson', 'Peter Izzo',
#         'Spencer Williams', 'Jamie Skaar', 'Alec Thompson', 'Daniel Tully',
#         'Pardeep Singh', 'PJ Henderson', 'Brandon Kieffer',
#         'Bryan Witzmann', 'Edward Naranjo', 'Garrett Aida', 'Jack Russell',
#         'JoMarri Gable', 'Ryan Fox'], dtype=object),
#  array(['Brandon Jones', 'Joe Coleman', 'Nayte Olukoya', 'Rodney Matthews',
#         'Olumide "Olu" Onajide', 'Rick Leach', 'Martin Gelbspan',
#         'Clayton Echard', 'Casey Woods', 'Leroy Arthur', 'Chris Sutton',
#         'Chris Gallant', 'Romeo Alexander', 'Will Urena',
#         'Lowell "LT" Murray IV', 'Mollique Johnson', 'Peter Izzo',
#         'Spencer Williams', 'Jamie Skaar', 'Alec Thompson', 'Daniel Tully',
#         'Pardeep Singh', 'PJ Henderson', 'Brandon Kieffer',
#         'Bryan Witzmann', 'Edward Naranjo', 'Garrett Aida', 'Jack Russell',
#         'JoMarri Gable', 'Ryan Fox'], dtype=object),
#  array(['Brandon Jones', 'Joe Coleman', 'Nayte Olukoya', 'Rodney Matthews',
#         'Olumide "Olu" Onajide', 'Rick Leach', 'Martin Gelbspan',
#         'Clayton Echard', 'Casey Woods', 'Leroy Arthur', 'Chris Sutton',
#         'Chris Gallant', 'Romeo Alexander', 'Will Urena',
#         'Lowell "LT" Murray IV', 'Mollique Johnson', 'Peter Izzo',
#         'Spencer Williams', 'Jamie Skaar', 'Alec Thompson', 'Daniel Tully',
#         'Pardeep Singh', 'PJ Henderson', 'Brandon Kieffer',
#         'Bryan Witzmann', 'Edward Naranjo', 'Garrett Aida', 'Jack Russell',
#         'JoMarri Gable', 'Ryan Fox'], dtype=object),
#  array(['Brandon Jones', 'Joe Coleman', 'Nayte Olukoya', 'Rodney Matthews',
#         'Olumide "Olu" Onajide', 'Rick Leach', 'Martin Gelbspan',
#         'Clayton Echard', 'Casey Woods', 'Leroy Arthur', 'Chris Sutton',
#         'Chris Gallant', 'Romeo Alexander', 'Will Urena',
#         'Lowell "LT" Murray IV', 'Mollique Johnson', 'Peter Izzo',
#         'Spencer Williams', 'Jamie Skaar', 'Alec Thompson', 'Daniel Tully',
#         'Pardeep Singh', 'PJ Henderson', 'Brandon Kieffer',
#         'Bryan Witzmann', 'Edward Naranjo', 'Garrett Aida', 'Jack Russell',
#         'JoMarri Gable', 'Ryan Fox'], dtype=object),
#  array(['Brandon Jones', 'Joe Coleman', 'Nayte Olukoya', 'Rodney Matthews',
#         'Olumide "Olu" Onajide', 'Rick Leach', 'Martin Gelbspan',
#         'Clayton Echard', 'Casey Woods', 'Leroy Arthur', 'Chris Sutton',
#         'Chris Gallant', 'Romeo Alexander', 'Will Urena',
#         'Lowell "LT" Murray IV', 'Mollique Johnson', 'Peter Izzo',
#         'Spencer Williams', 'Jamie Skaar', 'Alec Thompson', 'Daniel Tully',
#         'Pardeep Singh', 'PJ Henderson', 'Brandon Kieffer',
#         'Bryan Witzmann', 'Edward Naranjo', 'Garrett Aida', 'Jack Russell',
#         'JoMarri Gable', 'Ryan Fox'], dtype=object),
#  array(['Brandon Jones', 'Joe Coleman', 'Nayte Olukoya', 'Rodney Matthews',
#         'Olumide "Olu" Onajide', 'Rick Leach', 'Martin Gelbspan',
#         'Clayton Echard', 'Casey Woods', 'Leroy Arthur', 'Chris Sutton',
#         'Chris Gallant', 'Romeo Alexander', 'Will Urena',
#         'Lowell "LT" Murray IV', 'Mollique Johnson', 'Peter Izzo',
#         'Spencer Williams', 'Jamie Skaar', 'Alec Thompson', 'Daniel Tully',
#         'Pardeep Singh', 'PJ Henderson', 'Brandon Kieffer',
#         'Bryan Witzmann', 'Edward Naranjo', 'Garrett Aida', 'Jack Russell',
#         'JoMarri Gable', 'Ryan Fox'], dtype=object),
#  array(['Brandon Jones', 'Joe Coleman', 'Nayte Olukoya', 'Rodney Matthews',
#         'Olumide "Olu" Onajide', 'Rick Leach', 'Martin Gelbspan',
#         'Clayton Echard', 'Casey Woods', 'Leroy Arthur', 'Chris Sutton',
#         'Chris Gallant', 'Romeo Alexander', 'Will Urena',
#         'Lowell "LT" Murray IV', 'Mollique Johnson', 'Peter Izzo',
#         'Spencer Williams', 'Jamie Skaar', 'Alec Thompson', 'Daniel Tully',
#         'Pardeep Singh', 'PJ Henderson', 'Brandon Kieffer',
#         'Bryan Witzmann', 'Edward Naranjo', 'Garrett Aida', 'Jack Russell',
#         'JoMarri Gable', 'Ryan Fox'], dtype=object),
#  array(['Brandon Jones', 'Joe Coleman', 'Nayte Olukoya', 'Rodney Matthews',
#         'Olumide "Olu" Onajide', 'Rick Leach', 'Martin Gelbspan',
#         'Clayton Echard', 'Casey Woods', 'Leroy Arthur', 'Chris Sutton',
#         'Chris Gallant', 'Romeo Alexander', 'Will Urena',
#         'Lowell "LT" Murray IV', 'Mollique Johnson', 'Peter Izzo',
#         'Spencer Williams', 'Jamie Skaar', 'Alec Thompson', 'Daniel Tully',
#         'Pardeep Singh', 'PJ Henderson', 'Brandon Kieffer',
#         'Bryan Witzmann', 'Edward Naranjo', 'Garrett Aida', 'Jack Russell',
#         'JoMarri Gable', 'Ryan Fox'], dtype=object)]

# %% [markdown]
# #### Making that list into a DataFrame

# %%
vec_contestants = pd.DataFrame(data={"Contestants": df_of_lists})
vec_contestants
# Out:
#                                            Contestants
# 0    [Chris Siegfried, Drew Kenney, Brooks Forester...
# 1    [Chris Siegfried, Drew Kenney, Brooks Forester...
# 2    [Chris Siegfried, Drew Kenney, Brooks Forester...
# 3    [Chris Siegfried, Drew Kenney, Brooks Forester...
# 4    [Chris Siegfried, Drew Kenney, Brooks Forester...
# ..                                                 ...
# 114  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...
# 115  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...
# 116  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...
# 117  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...
# 118  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...
#
# [119 rows x 1 columns]

# %% [markdown]
# #### Adding that vector to the `season_data` matrix, and rename to `master_data`.

# %%
master_data = season_data.join(vec_contestants)
master_data
# Out:
#      Season  Episode                 Title  Date Aired  \
# 0         9        1                Week 1  2013-05-27
# 1         9        2                Week 2  2013-06-03
# 2         9        3                Week 3  2013-06-10
# 3         9        4                Week 4  2013-06-17
# 4         9        5                Week 5  2013-06-24
# ..      ...      ...                   ...         ...
# 114      18        7                Week 7  2021-11-30
# 115      18        8      The Men Tell All  2021-12-06
# 116      18        9                Week 8  2021-12-14
# 117      18       10                Week 9  2021-12-21
# 118      18       11  After the Final Rose  2021-12-21
#
#                                            Contestants
# 0    [Chris Siegfried, Drew Kenney, Brooks Forester...
# 1    [Chris Siegfried, Drew Kenney, Brooks Forester...
# 2    [Chris Siegfried, Drew Kenney, Brooks Forester...
# 3    [Chris Siegfried, Drew Kenney, Brooks Forester...
# 4    [Chris Siegfried, Drew Kenney, Brooks Forester...
# ..                                                 ...
# 114  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...
# 115  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...
# 116  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...
# 117  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...
# 118  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...
#
# [119 rows x 5 columns]

# %% [markdown]
# #### Now we create a column to contain a list of who was voted off in that episode

# %%
voted_off = pd.DataFrame(columns = ["Voted Off"])
master_data = master_data.join(voted_off)
master_data
# Out:
#      Season  Episode                 Title  Date Aired  \
# 0         9        1                Week 1  2013-05-27
# 1         9        2                Week 2  2013-06-03
# 2         9        3                Week 3  2013-06-10
# 3         9        4                Week 4  2013-06-17
# 4         9        5                Week 5  2013-06-24
# ..      ...      ...                   ...         ...
# 114      18        7                Week 7  2021-11-30
# 115      18        8      The Men Tell All  2021-12-06
# 116      18        9                Week 8  2021-12-14
# 117      18       10                Week 9  2021-12-21
# 118      18       11  After the Final Rose  2021-12-21
#
#                                            Contestants Voted Off
# 0    [Chris Siegfried, Drew Kenney, Brooks Forester...       NaN
# 1    [Chris Siegfried, Drew Kenney, Brooks Forester...       NaN
# 2    [Chris Siegfried, Drew Kenney, Brooks Forester...       NaN
# 3    [Chris Siegfried, Drew Kenney, Brooks Forester...       NaN
# 4    [Chris Siegfried, Drew Kenney, Brooks Forester...       NaN
# ..                                                 ...       ...
# 114  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...       NaN
# 115  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...       NaN
# 116  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...       NaN
# 117  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...       NaN
# 118  [Brandon Jones, Joe Coleman, Nayte Olukoya, Ro...       NaN
#
# [119 rows x 6 columns]

# %% [markdown]
# #### We have gone through the data in `master_data` after saving it to a CSV to perform some manual cleaning of episodes where no one gets voted off. Here, we pull back in the CSV as a DataFrame

# %%
master_data_clean = pd.read_csv("./master_data_clean.csv")
master_data_clean.drop(columns=["Unnamed: 0"], inplace=True)
master_data_clean
# Out:
#     Season  Episode   Title Date Aired  \
# 0        9        1  Week 1    5/27/13
# 1        9        2  Week 2     6/3/13
# 2        9        3  Week 3    6/10/13
# 3        9        4  Week 4    6/17/13
# 4        9        5  Week 5    6/24/13
# ..     ...      ...     ...        ...
# 95      18        4  Week 4    11/9/21
# 96      18        5  Week 5   11/16/21
# 97      18        6  Week 6   11/23/21
# 98      18        7  Week 7   11/30/21
# 99      18        9  Week 8   12/14/21
#
#                                           Contestants  Voted Off
# 0   ['Chris Siegfried' 'Drew Kenney' 'Brooks Fores...        NaN
# 1   ['Chris Siegfried' 'Drew Kenney' 'Brooks Fores...        NaN
# 2   ['Chris Siegfried' 'Drew Kenney' 'Brooks Fores...        NaN
# 3   ['Chris Siegfried' 'Drew Kenney' 'Brooks Fores...        NaN
# 4   ['Chris Siegfried' 'Drew Kenney' 'Brooks Fores...        NaN
# ..                                                ...        ...
# 95  ['Brandon Jones' 'Joe Coleman' 'Nayte Olukoya'...        NaN
# 96  ['Brandon Jones' 'Joe Coleman' 'Nayte Olukoya'...        NaN
# 97  ['Brandon Jones' 'Joe Coleman' 'Nayte Olukoya'...        NaN
# 98  ['Brandon Jones' 'Joe Coleman' 'Nayte Olukoya'...        NaN
# 99  ['Brandon Jones' 'Joe Coleman' 'Nayte Olukoya'...        NaN
#
# [100 rows x 6 columns]

# %% [markdown]
# #### Here we are sequentially creating a list of lists where each list represents which contestants were voted off during that episode.

# %%
# Global list of length 100 (to match master_data_clean)
all_voted_off = []

for season in seasons:
    
    # Getting the contestant data from each season
    comp_conts = contestant_data[season]
    # only looking at one season at a time from master_data_clean
    master_block = master_data_clean[master_data_clean["Season"] == season]

    # initializing a temporary list to be added to the global list
    season_voted_off = []
    
    # running through each episode in the season
    for episode in range(len(master_block)):

        # define the week
        week = master_block.iat[episode, 2]

        # initialize a temporary list of contestants to be added to the season list
        voted_off = []

        # for every contestant that season, see if their outcome (i.e. when they were voted off) matches the week
        # if so, add them to the voted off list for that week
        for contestant in range(len(comp_conts)):
            if comp_conts.iat[contestant, 1] == week:
                voted_off.append(comp_conts.iat[contestant, 0])
                
        # add that list to the season list of people voted off
        season_voted_off.append(voted_off)
        
    # we didnt want a list of lists of lists, so this simply breaks it down into a list of lists
    for vo in season_voted_off:
        all_voted_off.append(vo)

# %% [markdown]
# #### Checking to see if what we have is what we want, which is a list containing lists of every character voted off in each episode

# %%
all_voted_off
# Out:
# [['Diogo Custodio',
#   'Larry Burchett',
#   'Micah Heisler',
#   'Mike R.',
#   'Nick Roy',
#   'Jonathan Vollinger'],
#  ['Nick Mucci', 'Robert Graham', 'Will Reese'],
#  ['Brandon Andreen', 'Dan Cox', 'Brian Jarosinski'],
#  ['Zack Kalter', 'Brad McKinzie'],
#  ['Mikey Tenerelli', 'Ben Scott', 'Bryden Vukasin'],
#  ['James Case', 'Juan Pablo Galavis', 'Kasey Stewart'],
#  ['Michael Garofola'],
#  ['Zak Waddell'],
#  ['Brooks Forester'],
#  [],
#  ['Emil Schaffroth',
#   'Jason Leep',
#   'Josh Bauer',
#   'Mike Campanelli',
#   'Rudie Dane',
#   'Steven Woolworth'],
#  ['Carl King', 'Craig Muhlbauer', 'Nick Sutter'],
#  ['Bradley Wisk', 'Brett Melnick', 'Ron Worrell'],
#  ['Tasos Hernandez', 'Eric Hill'],
#  ['Andrew Poole', 'Marquel Martin', 'Patrick Jagodzinski'],
#  ['Joseph John "J.J." O\'Brien', 'Cody Sattler'],
#  ['Brian Osborne', 'Dylan Petitt'],
#  ['Marcus Grodd'],
#  ['Chris Soules'],
#  [],
#  ['Bradley Cox',
#   'David',
#   'Josh Seiter',
#   'Shawn Evans',
#   'Brady Toops',
#   'Ryan McDill'],
#  ['Cory Shivar', 'Daniel Finney', 'Kupah James'],
#  ['Clint Arlis', 'Tony Harris'],
#  ['Corey Stansell', 'Jonathan Holloway', 'Ryan Beckett'],
#  ['Joshua Albers', 'Justin Reich', 'Ian Thomson'],
#  ['Ben Zorn', 'Tanner Tolbert', 'John "J.J." Lane III'],
#  ['Jared Haibon', 'Joe Bailey', 'Chris Strandburg'],
#  ['Ben Higgins'],
#  [],
#  [],
#  ['Colin "Coley" Knust',
#   'Jake Patton',
#   'Jonathan Hamilton',
#   'Nicholas "Nick" Sharp',
#   'Peter Medina',
#   'Salvatore "Sal" DeJulio'],
#  ['Brandon Howell', 'James Spadafore', 'William "Will" Haduch'],
#  ['Ali Zahiri', 'Christian Bishop', 'Nicholas "Nick" Benvenutti'],
#  ['Daniel Maguire', 'James Fuertes', 'Brian "Chad" Johnson'],
#  ['Evan Bass', 'Grant Kemp', 'Vincent "Vinny" Ventiera'],
#  ['Derek Peth', 'Wells Adams'],
#  ['James Taylor', 'Alexander "Alex" Woytkiw'],
#  ['Luke Pell'],
#  ['Chase McNary'],
#  ['Jedidiah Ballard',
#   'Michael Black',
#   'Robert "Rob" Howard',
#   'Grant Hubsher',
#   'Blake Killpack',
#   'Milton LaCroix',
#   'Mohit Sehgal',
#   'Kyle Sherwood'],
#  ['Blake Elarbee', 'James "Jamey" Kocan', 'Lucas Yancey', 'DeMario Jackson'],
#  ['Brady Ervin',
#   'Kenneth "Diggy" Moreland',
#   'Bryce Powers',
#   'Frederick "Fred" Johnson'],
#  ['Ignacio "Iggy" Rodriguez', 'Jonathan Treece', 'Jack Stone'],
#  ['Anthony Battle', 'Josiah Graham', 'Lee Garrett'],
#  ['Anthony Battle', 'Josiah Graham', 'Lee Garrett'],
#  ['Aleksandr "Alex" Bordyukov', 'William "Will" Gaskins', 'Kenny Layne'],
#  ['Adam Gottschalk', 'Matthew "Matt" Munson'],
#  ['Dean Unglert'],
#  ['Eric Bigger'],
#  ['Chase Vergason',
#   'Christian Estrada',
#   'Darius Feaster',
#   'Grant Vandevanter',
#   'Joe Amabile',
#   'Kamil Nicalek',
#   'Jake Enyeart'],
#  ['Alex Templeman', 'Rickey Jasper', 'Trent Jespersen'],
#  ['Michael "Mike" Renner', 'Ryan Peterson', 'Clay Harbor'],
#  ['Christon Staples', 'Nicholas "Nick" Spetsas', 'Jean Blanc'],
#  ['John Graham', 'Jordan Kimball', 'David Ravitz'],
#  ['Connor Obrochta', 'Lincoln Adim', 'Chris Randone'],
#  ['William "Wills" Reid', 'Leandro "Leo" Dottavio'],
#  ['Colton Underwood'],
#  ['Jason Tartick'],
#  [],
#  ['Brian Bowles',
#   'Chasen Coscia',
#   'Hunter Jones',
#   'Joe Barsano',
#   'Matt Donald',
#   'Ryan Spirko',
#   'Thomas Staton',
#   'Scott Andersen'],
#  ['Connor Jenkins', 'Daron Blaylock', 'Matthew Spraggins'],
#  ['Cameron "Cam" Ayala', 'Joey Jones', 'Jonathan Saunders', 'Tyler Gwozdz†'],
#  ['John Paul Jones', 'Matteo Valles', 'Luke Stone'],
#  ['Devin Harris', 'Grant Eckel', 'Kevin Fortenberry'],
#  ['Dustin Kendrick', 'Dylan Barbour'],
#  ['Garrett Powell', 'Mike Johnson', 'Connor Saeli'],
#  [],
#  ['Peter Weber', 'Luke Parker'],
#  [],
#  ['AJ Yalawan',
#   'Chris Conran',
#   'Jeremy Higgins',
#   'Jordan Manier',
#   'Mike Tobin',
#   'Page Pressley',
#   'Robby Stahl',
#   'Tyler Cottrill'],
#  ['Blake Monar',
#   'Garin Flowers',
#   'Tyler Smith',
#   'Yosef Aborady',
#   'Brandon Goss'],
#  ['Zach Jackson'],
#  [],
#  ['Jay Smith', 'Montel Hill', 'Peter Giannikopoulos', 'Jason Foster'],
#  ['Chasen Nick', 'Joe Park', 'Jordan Chapman', 'Kenny Braasch'],
#  ['Uzoma "Eazy" Nwachukwu'],
#  ['Demar Jackson', 'Ed Waisbrot', 'Spencer Robertson'],
#  ['Bennett Jordan', 'Noah Erb', 'Riley Christian', 'Blake Moynes'],
#  [],
#  ['Ivan Hall', 'Brendan Morais'],
#  [],
#  [],
#  ['Austin Tinsley',
#   'Brandon Torres',
#   'Gabriel Everett',
#   'Jeff Caravello',
#   'Landon Goesling',
#   'Marcus Lathan',
#   'Marty Hargrove'],
#  ['Garrett Schwartz', 'John Hersey', 'Karl Smith', 'Kyle Howard', 'Cody Menk'],
#  ['Christian Smith', 'Conor Costello', 'David Scott', 'Thomas Jacobs'],
#  ['Andrew Milcovich', 'Josh Tylerbest', 'Quartney Mixon'],
#  ['Aaron Clancy',
#   'Hunter Montgomery',
#   'James Bonsall',
#   'Tré Cooper',
#   'Connor Brennan'],
#  ['Andrew Spencer', 'Mike Planeta', 'Brendan Scanzano'],
#  ['Greg Grippo', 'Michael Allio'],
#  ['Justin Glaze'],
#  [],
#  [],
#  ['Brandon Kieffer',
#   'Bryan Witzmann',
#   'Edward Naranjo',
#   'Garrett Aida',
#   'Jack Russell',
#   'JoMarri Gable',
#   'Ryan Fox'],
#  ['Alec Thompson', 'Daniel Tully', 'Pardeep Singh', 'PJ Henderson'],
#  ['Lowell "LT" Murray IV',
#   'Mollique Johnson',
#   'Peter Izzo',
#   'Spencer Williams',
#   'Jamie Skaar'],
#  ['Chris Gallant', 'Romeo Alexander', 'Will Urena'],
#  ['Casey Woods', 'Leroy Arthur', 'Chris Sutton'],
#  ['Olumide "Olu" Onajide', 'Rick Leach', 'Martin Gelbspan', 'Clayton Echard'],
#  ['Rodney Matthews'],
#  []]

# %% [markdown]
# #### Now we need to add that vector to the column for the `master_data`!

# %%
# removing placeholder Voted Off column
master_data_clean.drop(columns=["Voted Off"], inplace=True)

# %%
# making our data into a dataframe for easy joining
avo = pd.DataFrame(data={"Voted Off": all_voted_off})

# joining
master_data_final = master_data_clean.join(avo)

# %%
master_data_final
# Out:
#     Season  Episode   Title Date Aired  \
# 0        9        1  Week 1    5/27/13
# 1        9        2  Week 2     6/3/13
# 2        9        3  Week 3    6/10/13
# 3        9        4  Week 4    6/17/13
# 4        9        5  Week 5    6/24/13
# ..     ...      ...     ...        ...
# 95      18        4  Week 4    11/9/21
# 96      18        5  Week 5   11/16/21
# 97      18        6  Week 6   11/23/21
# 98      18        7  Week 7   11/30/21
# 99      18        9  Week 8   12/14/21
#
#                                           Contestants  \
# 0   ['Chris Siegfried' 'Drew Kenney' 'Brooks Fores...
# 1   ['Chris Siegfried' 'Drew Kenney' 'Brooks Fores...
# 2   ['Chris Siegfried' 'Drew Kenney' 'Brooks Fores...
# 3   ['Chris Siegfried' 'Drew Kenney' 'Brooks Fores...
# 4   ['Chris Siegfried' 'Drew Kenney' 'Brooks Fores...
# ..                                                ...
# 95  ['Brandon Jones' 'Joe Coleman' 'Nayte Olukoya'...
# 96  ['Brandon Jones' 'Joe Coleman' 'Nayte Olukoya'...
# 97  ['Brandon Jones' 'Joe Coleman' 'Nayte Olukoya'...
# 98  ['Brandon Jones' 'Joe Coleman' 'Nayte Olukoya'...
# 99  ['Brandon Jones' 'Joe Coleman' 'Nayte Olukoya'...
#
#                                             Voted Off
# 0   [Diogo Custodio, Larry Burchett, Micah Heisler...
# 1             [Nick Mucci, Robert Graham, Will Reese]
# 2        [Brandon Andreen, Dan Cox, Brian Jarosinski]
# 3                        [Zack Kalter, Brad McKinzie]
# 4        [Mikey Tenerelli, Ben Scott, Bryden Vukasin]
# ..                                                ...
# 95       [Chris Gallant, Romeo Alexander, Will Urena]
# 96          [Casey Woods, Leroy Arthur, Chris Sutton]
# 97  [Olumide "Olu" Onajide, Rick Leach, Martin Gel...
# 98                                  [Rodney Matthews]
# 99                                                 []
#
# [100 rows x 6 columns]

# %% [markdown]
# #### Finally, saving that to a CSV for sharing among teammates

# %%
master_data_final.to_csv("./wikipedia_master.csv")
